# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # <center>REST API</center>
# ---

# %% [markdown]
# ## Overview
# Application Programming Iterface (API) it's basically a fancy way of saying that it's a way two pieces of software interact with ome another, no matter in which programming language both the softwares were created.
#
# * **REST API:** A REST API is an application programming interface that follows the principles of REST (REpresentational State Transfer), an architectural style for creating web services. A REST API allows different applications or devices to communicate with each other using standard methods like GET, POST, PUT and DELETE.
#
# * **JSON:** JSON (JavaScript Object Notation) is a data format that is commonly used by REST APIs to exchange information between a client and a server. A REST API can use different data formats to transfer information between the client and the server, but JSON is preferred by many developers because it is lightweight and easy to parse.
#
# * **Endpoint:** An endpoint is a URL that defines how a client can access a resource or perform an operation on that resource using HTTP methods. For example, `https://mydomain/user/123?format=json` is an endpoint that returns the user with id 123 in JSON format. A REST API should use nouns instead of verbs in the endpoints to indicate what each of them does. For example, **GET** /users should return all users, **POST** /users should create a new user, **PUT** /users/123 should update user 123, and **DELETE** /users/123 should delete user 123
#
# ## Some of the benefits of using REST APIs are:
#
# * They are lightweight and fast, because they rely on the HTTP standard and can use different data formats such as JSON, XML, HTML, etc.
# * They are independent and decoupled, because they separate the data storage and the UI from the server. This means that developers can work on different parts of a project independently and try out multiple environments as needed.
# * They are scalable and flexible, because they can handle different types of requests and responses using HTTP methods. This also makes them easier to cache and reuse.

# %% [markdown]
# ## Consuming Stackoverflow's Rest Api

# %%
# import libraries
import requests
import json

# %% [markdown]
# ### make a request to any page

# %%
# make a request to any page
requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
# Out:
# <Response [200]>

# %%
# store the response
response = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### access the data returned to response in json format

# %%
# returns all the data that we have got if we request in a web browser or in postman
response.json()
# Out:
# {'items': [{'tags': ['javascript', 'regex'],
#    'owner': {'account_id': 25044593,
#     'reputation': 13,
#     'user_id': 18901145,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/774d60a3697174d37ea6855bdefce0bd?s=256&d=identicon&r=PG',
#     'display_name': 'richiecunningham',
#     'link': 'https://stackoverflow.com/users/18901145/richiecunningham'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530157,
#    'creation_date': 1677530049,
#    'last_edit_date': 1677530157,
#    'question_id': 75585301,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585301/i-am-looking-for-the-regex-javascript-to-grab-any-numbers-that-appear-within-a',
#    'title': 'I am looking for the regex (JavaScript) to grab any numbers that appear within a bracket'},
#   {'tags': ['flutter', 'path', 'audio-player', 'file-manager'],
#    'owner': {'account_id': 17995509,
#     'reputation': 745,
#     'user_id': 13078639,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/TON6G.png?s=256&g=1',
#     'display_name': 'amit.flutter',
#     'link': 'https://stackoverflow.com/users/13078639/amit-flutter'},
#    'is_answered': False,
#    'view_count': 359,
#    'answer_count': 1,
#    'score': 3,
#    'last_activity_date': 1677530155,
#    'creation_date': 1662966974,
#    'question_id': 73685676,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73685676/difference-between-application-documents-directory-and-support-directory-in-path',
#    'title': 'Difference between Application Documents Directory and Support Directory in path_provider?'},
#   {'tags': ['git', 'github', 'visual-studio-code'],
#    'owner': {'account_id': 6642963,
#     'reputation': 1,
#     'user_id': 5128095,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/878192538885167/picture?type=large',
#     'display_name': 'Ian Cross',
#     'link': 'https://stackoverflow.com/users/5128095/ian-cross'},
#    'is_answered': False,
#    'view_count': 1,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530154,
#    'creation_date': 1677530154,
#    'question_id': 75585310,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585310/problem-when-trying-to-push-files-to-from-vs-code-to-github-repo',
#    'title': 'Problem when trying to push files to from vs code to github repo'},
#   {'tags': ['asp.net',
#     'asp.net-mvc',
#     'redis',
#     'session-state',
#     'azure-redis-cache'],
#    'owner': {'account_id': 2117126,
#     'reputation': 996,
#     'user_id': 1881147,
#     'user_type': 'registered',
#     'accept_rate': 20,
#     'profile_image': 'https://www.gravatar.com/avatar/c3d3a62ffdb2ea6bb3eea84e902007b2?s=256&d=identicon&r=PG',
#     'display_name': 'jay',
#     'link': 'https://stackoverflow.com/users/1881147/jay'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530154,
#    'creation_date': 1677530154,
#    'question_id': 75585309,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585309/asp-net-session-state-redis-cache-managed-identity-or-securing-accesskey',
#    'title': 'asp net session state redis cache managed identity or securing accessKey'},
#   {'tags': ['c', 'authentication', 'passwords'],
#    'owner': {'account_id': 27805166,
#     'reputation': 1,
#     'user_id': 21228735,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp70meT1CeNLmntlzrCwmhXU9lKW5bw0q543RhkQ=k-s256',
#     'display_name': 'mr. c',
#     'link': 'https://stackoverflow.com/users/21228735/mr-c'},
#    'is_answered': False,
#    'view_count': 30,
#    'closed_date': 1677529609,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530149,
#    'creation_date': 1677527377,
#    'question_id': 75584947,
#    'link': 'https://stackoverflow.com/questions/75584947/login-authentification-in-c',
#    'closed_reason': 'Needs details or clarity',
#    'title': 'login authentification in c'},
#   {'tags': ['sql', 'postgresql', 'postgres-14'],
#    'owner': {'account_id': 6610892,
#     'reputation': 43,
#     'user_id': 5106065,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a645e5171071881b3c8df1f7b5565277?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'nikhil raj',
#     'link': 'https://stackoverflow.com/users/5106065/nikhil-raj'},
#    'is_answered': False,
#    'view_count': 23,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530138,
#    'creation_date': 1677525064,
#    'last_edit_date': 1677530138,
#    'question_id': 75584642,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584642/temporary-table-is-not-getting-created-inside-function-in-postgres',
#    'title': 'Temporary table is not getting created inside Function in postgres'},
#   {'tags': ['javascript', 'html'],
#    'owner': {'account_id': 3325800,
#     'reputation': 35,
#     'user_id': 2795916,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://graph.facebook.com/100000457716623/picture?type=large',
#     'display_name': 'Rik Eckhardt',
#     'link': 'https://stackoverflow.com/users/2795916/rik-eckhardt'},
#    'is_answered': True,
#    'view_count': 232,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530130,
#    'creation_date': 1520848922,
#    'last_edit_date': 1677530130,
#    'question_id': 49232478,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/49232478/how-do-i-group-answers-in-categories-javascript',
#    'title': 'How do I group answers in categories JavaScript?'},
#   {'tags': ['python', 'amazon-web-services', 'pyspark', 'parquet'],
#    'owner': {'account_id': 21746826,
#     'reputation': 181,
#     'user_id': 16053370,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/4524108264284040/picture?type=large',
#     'display_name': 'Carlos Eduardo Bilar Rodrigues',
#     'link': 'https://stackoverflow.com/users/16053370/carlos-eduardo-bilar-rodrigues'},
#    'is_answered': False,
#    'view_count': 9,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530121,
#    'creation_date': 1677524587,
#    'last_edit_date': 1677525304,
#    'question_id': 75584567,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584567/how-to-search-and-delete-specific-lines-from-a-parquet-file-in-pyspark-data-pu',
#    'title': 'How to search and delete specific lines from a parquet file in pyspark? (data purge)'},
#   {'tags': ['php', 'html', 'mysql'],
#    'owner': {'account_id': 27894295,
#     'reputation': 1,
#     'user_id': 21299947,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxaerhkbadtLQK4MXnnngOz0k6ge3YwsR0_uWcP5Ow=k-s256',
#     'display_name': 'ThatOllieo',
#     'link': 'https://stackoverflow.com/users/21299947/thatollieo'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530117,
#    'creation_date': 1677530117,
#    'question_id': 75585306,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585306/inserting-file-into-blob-field-php-mysql-wont-accept-any-data-i-attempt-t',
#    'title': 'Inserting file into blob field [PHP] [mysql] - Won&#39;t accept any data I attempt to insert?'},
#   {'tags': ['azure', 'selenium-webdriver', 'azure-devops'],
#    'owner': {'account_id': 12608018,
#     'reputation': 1,
#     'user_id': 9168223,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-Q3GhRSF4u10/AAAAAAAAAAI/AAAAAAAABow/hi4SwAkiULk/photo.jpg?sz=256',
#     'display_name': 'Sridevi Srinivasan',
#     'link': 'https://stackoverflow.com/users/9168223/sridevi-srinivasan'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530108,
#    'creation_date': 1677530108,
#    'question_id': 75585305,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585305/where-in-azure-is-my-csv-error-files-from-the-application-are-stored-in-azure',
#    'title': 'Where in Azure is my .csv error files from the application are stored in Azure?'},
#   {'tags': ['java', 'docker', 'playwright-java'],
#    'owner': {'account_id': 10030252,
#     'reputation': 13,
#     'user_id': 19767912,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c1deaa774ac2c482d9f009cdf7b462a2?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'user982455',
#     'link': 'https://stackoverflow.com/users/19767912/user982455'},
#    'is_answered': False,
#    'view_count': 35,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530107,
#    'creation_date': 1676589418,
#    'question_id': 75478872,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75478872/run-spring-boot-application-using-playwright-java-in-docker-container',
#    'title': 'Run Spring Boot application using Playwright Java in Docker container'},
#   {'tags': ['irc'],
#    'owner': {'account_id': 25892074,
#     'reputation': 1,
#     'user_id': 19619322,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/55Z5y.gif?s=256&g=1',
#     'display_name': 'JerryBerry12',
#     'link': 'https://stackoverflow.com/users/19619322/jerryberry12'},
#    'is_answered': False,
#    'view_count': 11,
#    'closed_date': 1677523406,
#    'answer_count': 0,
#    'score': -3,
#    'last_activity_date': 1677530107,
#    'creation_date': 1677522918,
#    'last_edit_date': 1677530107,
#    'question_id': 75584305,
#    'link': 'https://stackoverflow.com/questions/75584305/how-do-i-become-a-irc-netadmin',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'How do I become a IRC NetAdmin?'},
#   {'tags': ['python', 'pandas', 'matplotlib', 'bar-chart'],
#    'owner': {'account_id': 23108188,
#     'reputation': 60,
#     'user_id': 17216471,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhzMVoSI4DhEnY8S_oCJe5rwkRh39ulkBpXd-iZQOo=k-s256',
#     'display_name': 'Colton Campbell',
#     'link': 'https://stackoverflow.com/users/17216471/colton-campbell'},
#    'is_answered': False,
#    'view_count': 9,
#    'closed_date': 1677530066,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530099,
#    'creation_date': 1677529339,
#    'question_id': 75585201,
#    'link': 'https://stackoverflow.com/questions/75585201/using-matplotlib-and-pandas-how-can-i-create-n-number-of-overlapping-bar-charts',
#    'closed_reason': 'Duplicate',
#    'title': 'Using Matplotlib and Pandas, how can I create n-number of overlapping bar charts with n-number of overlapping axes?'},
#   {'tags': ['c++'],
#    'owner': {'account_id': 3916521,
#     'reputation': 31,
#     'user_id': 3240228,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'user3240228',
#     'link': 'https://stackoverflow.com/users/3240228/user3240228'},
#    'is_answered': False,
#    'view_count': 48,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1677530098,
#    'creation_date': 1677523422,
#    'last_edit_date': 1677530098,
#    'question_id': 75584381,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584381/c-cannot-pass-string-literal-const-char-to-a-function-with-parameter-type',
#    'title': 'C++ Cannot pass string literal &#39;const char []&#39; to a function with parameter type &#39;const T&amp;&#39; where T is typedef of char[]'},
#   {'tags': ['scala', 'haskell', 'types'],
#    'owner': {'account_id': 370114,
#     'reputation': 2134,
#     'user_id': 717858,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://i.stack.imgur.com/ewjPh.jpg?s=256&g=1',
#     'display_name': 'Todd O&#39;Bryan',
#     'link': 'https://stackoverflow.com/users/717858/todd-obryan'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530091,
#    'creation_date': 1677530091,
#    'question_id': 75585304,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585304/scala-equivalent-of-haskell-type-constructor-inverse',
#    'title': 'Scala equivalent of Haskell type constructor/inverse?'},
#   {'tags': ['aws-lambda', 'aws-api-gateway', 'aws-cdk', 'aws-cdk-typescript'],
#    'owner': {'account_id': 2793197,
#     'reputation': 285,
#     'user_id': 2403018,
#     'user_type': 'registered',
#     'accept_rate': 25,
#     'profile_image': 'https://www.gravatar.com/avatar/222b5d55e427f25099151d25adf105d2?s=256&d=identicon&r=PG',
#     'display_name': 'user2403018',
#     'link': 'https://stackoverflow.com/users/2403018/user2403018'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530078,
#    'creation_date': 1677530078,
#    'question_id': 75585303,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585303/template-openapi-template-for-aws-apigateway-specrestapi-from-another-stack',
#    'title': 'Template openapi template for aws_apigateway.SpecRestApi from another stack'},
#   {'tags': ['c++', 'c', 'printing', 'floating-point', 'formatting'],
#    'owner': {'account_id': 2213450,
#     'reputation': 3667,
#     'user_id': 1954677,
#     'user_type': 'registered',
#     'accept_rate': 61,
#     'profile_image': 'https://www.gravatar.com/avatar/c95604a787536a0cfd261da70adb0e09?s=256&d=identicon&r=PG',
#     'display_name': 'flonk',
#     'link': 'https://stackoverflow.com/users/1954677/flonk'},
#    'is_answered': False,
#    'view_count': 74,
#    'answer_count': 3,
#    'score': 3,
#    'last_activity_date': 1677530076,
#    'creation_date': 1677494025,
#    'last_edit_date': 1677524571,
#    'question_id': 75579337,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75579337/how-to-use-c-c-format-specifiers-to-achieve-the-same-as-g-but-with-1-inst',
#    'title': 'How to use C/C++ format specifiers to achieve the same as &quot;g&quot; but with &quot;1.&quot; instead of &quot;1.0&quot;'},
#   {'tags': ['reactjs', 'firebase', 'react-native', 'expo'],
#    'owner': {'account_id': 20399957,
#     'reputation': 512,
#     'user_id': 14965903,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-v_Y_3faTBjw/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmgPBmjFnYxdF3BoI1-THONgrMfJQ/s96-c/photo.jpg?sz=256',
#     'display_name': 'newbie coder',
#     'link': 'https://stackoverflow.com/users/14965903/newbie-coder'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530072,
#    'creation_date': 1677526145,
#    'question_id': 75584771,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584771/upgrading-expo-can-not-start-because-of-the-issue-with-asyncstorage-and-firebase',
#    'title': 'Upgrading expo can not start because of the issue with AsyncStorage and firebase auth'},
#   {'tags': ['javascript', 'html', 'css'],
#    'owner': {'account_id': 27871532,
#     'reputation': 13,
#     'user_id': 21281950,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYXyS2ABsXqXHQpfiRN4GfDpdmfKY3N2IGdsJtt=k-s256',
#     'display_name': 'jhon barns',
#     'link': 'https://stackoverflow.com/users/21281950/jhon-barns'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530066,
#    'creation_date': 1677529675,
#    'last_edit_date': 1677530066,
#    'question_id': 75585245,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585245/how-to-resize-a-css-button-and-keep-the-inner-image-to-fit',
#    'title': 'How to resize a css button and keep the inner image to fit?'},
#   {'tags': ['c++'],
#    'owner': {'account_id': 1416313,
#     'reputation': 3812,
#     'user_id': 1341921,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/c149b4e22dece7405c2c85b74af18b57?s=256&d=identicon&r=PG',
#     'display_name': 'pmoubed',
#     'link': 'https://stackoverflow.com/users/1341921/pmoubed'},
#    'is_answered': True,
#    'view_count': 56,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1677530053,
#    'creation_date': 1677526197,
#    'last_edit_date': 1677529077,
#    'question_id': 75584779,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584779/is-this-pointer-valid-during-data-member-destruction',
#    'title': 'Is &quot;this&quot; pointer valid during data member destruction?'},
#   {'tags': ['routes', 'asp.net-core-mvc', 'cookie-authentication'],
#    'owner': {'account_id': 4352277,
#     'reputation': 13,
#     'user_id': 3552172,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'user3552172',
#     'link': 'https://stackoverflow.com/users/3552172/user3552172'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530051,
#    'creation_date': 1677525777,
#    'last_edit_date': 1677530051,
#    'question_id': 75584724,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584724/asp-net-core-incorrect-route-for-loginpath',
#    'title': 'ASP.NET Core Incorrect Route for LoginPath'},
#   {'tags': ['python', 'pandas', 'tensorflow', 'pickle', 'fastapi'],
#    'owner': {'account_id': 19182486,
#     'reputation': 57,
#     'user_id': 14013882,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e342794f63a1fa02acd7229bed658b81?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'gmelgkermglermgmrelkgm',
#     'link': 'https://stackoverflow.com/users/14013882/gmelgkermglermgmrelkgm'},
#    'is_answered': False,
#    'view_count': 54,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530049,
#    'creation_date': 1673909253,
#    'last_edit_date': 1673978521,
#    'question_id': 75140407,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75140407/dictionary-update-sequence-error-with-tensorflow-fastapi',
#    'title': 'Dictionary Update Sequence Error with Tensorflow + FastAPI'},
#   {'tags': ['pandas', 'dataframe'],
#    'owner': {'account_id': 25553802,
#     'reputation': 13,
#     'user_id': 19337723,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJx2n5DD9v8pES8u7MT9_xvN7evqWjI-z8wXIPG4=k-s256',
#     'display_name': 'M Kravets',
#     'link': 'https://stackoverflow.com/users/19337723/m-kravets'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530046,
#    'creation_date': 1677529902,
#    'question_id': 75585283,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585283/dataframe-merging-with-replacing-value',
#    'title': 'DataFrame merging with replacing value'},
#   {'tags': ['shell', 'unix'],
#    'owner': {'account_id': 10013677,
#     'reputation': 47,
#     'user_id': 7405752,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9ca2e32f852a8fd34ee087bc47212717?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'AKPuvvada',
#     'link': 'https://stackoverflow.com/users/7405752/akpuvvada'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530045,
#    'creation_date': 1677530045,
#    'question_id': 75585298,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585298/mail-not-working-in-script-same-way-it-is-working-from-command-line',
#    'title': '&#39;mail&#39; not working in Script same way it is working from command line'},
#   {'tags': ['python', 'pandas', 'warnings', 'future', 'series'],
#    'owner': {'account_id': 27894134,
#     'reputation': 1,
#     'user_id': 21299829,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYHKf-fKFPkOwFydtuyk3WwuLQQfuOnwvCeGIOG=k-s256',
#     'display_name': 'Trevor Noah',
#     'link': 'https://stackoverflow.com/users/21299829/trevor-noah'},
#    'is_answered': False,
#    'view_count': 18,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1677530044,
#    'creation_date': 1677528222,
#    'last_edit_date': 1677530044,
#    'question_id': 75585066,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585066/futurewarning-the-default-dtype-for-empty-series-will-be-object-instead-of-f',
#    'title': 'FutureWarning: The default dtype for empty Series will be &#39;object&#39; instead of &#39;float64&#39; in a future version'},
#   {'tags': ['java', 'split', 'tokenize'],
#    'owner': {'account_id': 22962500,
#     'reputation': 1,
#     'user_id': 17092122,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/AvOav.jpg?s=256&g=1',
#     'display_name': 'Julia',
#     'link': 'https://stackoverflow.com/users/17092122/julia'},
#    'is_answered': False,
#    'view_count': 27,
#    'closed_date': 1677529080,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1677530044,
#    'creation_date': 1677528616,
#    'last_edit_date': 1677529083,
#    'question_id': 75585118,
#    'link': 'https://stackoverflow.com/questions/75585118/tokenize-the-string',
#    'closed_reason': 'Duplicate',
#    'title': 'Tokenize the string'},
#   {'tags': ['c#',
#     'arrays',
#     'memory-management',
#     'out-of-memory',
#     'floyd-warshall'],
#    'owner': {'account_id': 5370447,
#     'reputation': 15551,
#     'user_id': 4279155,
#     'user_type': 'registered',
#     'accept_rate': 55,
#     'profile_image': 'https://i.stack.imgur.com/Gve3F.png?s=256&g=1',
#     'display_name': 'Dominique',
#     'link': 'https://stackoverflow.com/users/4279155/dominique'},
#    'is_answered': False,
#    'view_count': 159,
#    'bounty_amount': 200,
#    'bounty_closes_date': 1677762141,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1677530043,
#    'creation_date': 1675179537,
#    'last_edit_date': 1677228153,
#    'question_id': 75299523,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75299523/how-to-handle-arrays-of-extremely-large-strings-in-c',
#    'title': 'How to handle arrays of extremely large strings in C#'},
#   {'tags': ['flutter', 'dart'],
#    'owner': {'account_id': 13727122,
#     'reputation': 337,
#     'user_id': 9905602,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/YBDjb.jpg?s=256&g=1',
#     'display_name': 'Giuseppe Cianci',
#     'link': 'https://stackoverflow.com/users/9905602/giuseppe-cianci'},
#    'is_answered': True,
#    'view_count': 882,
#    'accepted_answer_id': 70963189,
#    'answer_count': 1,
#    'score': 3,
#    'last_activity_date': 1677530030,
#    'creation_date': 1643818804,
#    'last_edit_date': 1643871563,
#    'question_id': 70959115,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70959115/difference-between-casting-with-cast-method-and-as-keyword',
#    'title': 'Difference between casting with &#39;cast&#39; method and &#39;as&#39; keyword'},
#   {'tags': ['javascript', 'async-await', 'axios'],
#    'owner': {'account_id': 27894334,
#     'reputation': 1,
#     'user_id': 21299974,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxZJWsBLKZfQNKgAgMfhpIkiFAwAsBizwI9M8gri=k-s256',
#     'display_name': 'hori',
#     'link': 'https://stackoverflow.com/users/21299974/hori'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677530025,
#    'creation_date': 1677530025,
#    'question_id': 75585296,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75585296/how-can-it-be-undefined',
#    'title': 'How can it be undefined?'},
#   {'tags': ['rust', 'types'],
#    'owner': {'account_id': 18618506,
#     'reputation': 320,
#     'user_id': 13575954,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/DjxtL.jpg?s=256&g=1',
#     'display_name': 'kalkronline',
#     'link': 'https://stackoverflow.com/users/13575954/kalkronline'},
#    'is_answered': True,
#    'view_count': 16,
#    'accepted_answer_id': 75584111,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677530011,
#    'creation_date': 1677521426,
#    'question_id': 75584067,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75584067/how-to-specify-the-unused-return-type-of-a-generic-function',
#    'title': 'How to Specify the Unused Return Type of a Generic Function?'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 298}

# %% [markdown]
# ### lets explore one of the elements of the response data

# %%
response.json()["items"]
# Out:
# [{'tags': ['javascript', 'regex'],
#   'owner': {'account_id': 25044593,
#    'reputation': 13,
#    'user_id': 18901145,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/774d60a3697174d37ea6855bdefce0bd?s=256&d=identicon&r=PG',
#    'display_name': 'richiecunningham',
#    'link': 'https://stackoverflow.com/users/18901145/richiecunningham'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530157,
#   'creation_date': 1677530049,
#   'last_edit_date': 1677530157,
#   'question_id': 75585301,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585301/i-am-looking-for-the-regex-javascript-to-grab-any-numbers-that-appear-within-a',
#   'title': 'I am looking for the regex (JavaScript) to grab any numbers that appear within a bracket'},
#  {'tags': ['flutter', 'path', 'audio-player', 'file-manager'],
#   'owner': {'account_id': 17995509,
#    'reputation': 745,
#    'user_id': 13078639,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/TON6G.png?s=256&g=1',
#    'display_name': 'amit.flutter',
#    'link': 'https://stackoverflow.com/users/13078639/amit-flutter'},
#   'is_answered': False,
#   'view_count': 359,
#   'answer_count': 1,
#   'score': 3,
#   'last_activity_date': 1677530155,
#   'creation_date': 1662966974,
#   'question_id': 73685676,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73685676/difference-between-application-documents-directory-and-support-directory-in-path',
#   'title': 'Difference between Application Documents Directory and Support Directory in path_provider?'},
#  {'tags': ['git', 'github', 'visual-studio-code'],
#   'owner': {'account_id': 6642963,
#    'reputation': 1,
#    'user_id': 5128095,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/878192538885167/picture?type=large',
#    'display_name': 'Ian Cross',
#    'link': 'https://stackoverflow.com/users/5128095/ian-cross'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530154,
#   'creation_date': 1677530154,
#   'question_id': 75585310,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585310/problem-when-trying-to-push-files-to-from-vs-code-to-github-repo',
#   'title': 'Problem when trying to push files to from vs code to github repo'},
#  {'tags': ['asp.net',
#    'asp.net-mvc',
#    'redis',
#    'session-state',
#    'azure-redis-cache'],
#   'owner': {'account_id': 2117126,
#    'reputation': 996,
#    'user_id': 1881147,
#    'user_type': 'registered',
#    'accept_rate': 20,
#    'profile_image': 'https://www.gravatar.com/avatar/c3d3a62ffdb2ea6bb3eea84e902007b2?s=256&d=identicon&r=PG',
#    'display_name': 'jay',
#    'link': 'https://stackoverflow.com/users/1881147/jay'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530154,
#   'creation_date': 1677530154,
#   'question_id': 75585309,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585309/asp-net-session-state-redis-cache-managed-identity-or-securing-accesskey',
#   'title': 'asp net session state redis cache managed identity or securing accessKey'},
#  {'tags': ['c', 'authentication', 'passwords'],
#   'owner': {'account_id': 27805166,
#    'reputation': 1,
#    'user_id': 21228735,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp70meT1CeNLmntlzrCwmhXU9lKW5bw0q543RhkQ=k-s256',
#    'display_name': 'mr. c',
#    'link': 'https://stackoverflow.com/users/21228735/mr-c'},
#   'is_answered': False,
#   'view_count': 30,
#   'closed_date': 1677529609,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530149,
#   'creation_date': 1677527377,
#   'question_id': 75584947,
#   'link': 'https://stackoverflow.com/questions/75584947/login-authentification-in-c',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'login authentification in c'},
#  {'tags': ['sql', 'postgresql', 'postgres-14'],
#   'owner': {'account_id': 6610892,
#    'reputation': 43,
#    'user_id': 5106065,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/a645e5171071881b3c8df1f7b5565277?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'nikhil raj',
#    'link': 'https://stackoverflow.com/users/5106065/nikhil-raj'},
#   'is_answered': False,
#   'view_count': 23,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530138,
#   'creation_date': 1677525064,
#   'last_edit_date': 1677530138,
#   'question_id': 75584642,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584642/temporary-table-is-not-getting-created-inside-function-in-postgres',
#   'title': 'Temporary table is not getting created inside Function in postgres'},
#  {'tags': ['javascript', 'html'],
#   'owner': {'account_id': 3325800,
#    'reputation': 35,
#    'user_id': 2795916,
#    'user_type': 'registered',
#    'accept_rate': 0,
#    'profile_image': 'https://graph.facebook.com/100000457716623/picture?type=large',
#    'display_name': 'Rik Eckhardt',
#    'link': 'https://stackoverflow.com/users/2795916/rik-eckhardt'},
#   'is_answered': True,
#   'view_count': 232,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530130,
#   'creation_date': 1520848922,
#   'last_edit_date': 1677530130,
#   'question_id': 49232478,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/49232478/how-do-i-group-answers-in-categories-javascript',
#   'title': 'How do I group answers in categories JavaScript?'},
#  {'tags': ['python', 'amazon-web-services', 'pyspark', 'parquet'],
#   'owner': {'account_id': 21746826,
#    'reputation': 181,
#    'user_id': 16053370,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/4524108264284040/picture?type=large',
#    'display_name': 'Carlos Eduardo Bilar Rodrigues',
#    'link': 'https://stackoverflow.com/users/16053370/carlos-eduardo-bilar-rodrigues'},
#   'is_answered': False,
#   'view_count': 9,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530121,
#   'creation_date': 1677524587,
#   'last_edit_date': 1677525304,
#   'question_id': 75584567,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584567/how-to-search-and-delete-specific-lines-from-a-parquet-file-in-pyspark-data-pu',
#   'title': 'How to search and delete specific lines from a parquet file in pyspark? (data purge)'},
#  {'tags': ['php', 'html', 'mysql'],
#   'owner': {'account_id': 27894295,
#    'reputation': 1,
#    'user_id': 21299947,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxaerhkbadtLQK4MXnnngOz0k6ge3YwsR0_uWcP5Ow=k-s256',
#    'display_name': 'ThatOllieo',
#    'link': 'https://stackoverflow.com/users/21299947/thatollieo'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530117,
#   'creation_date': 1677530117,
#   'question_id': 75585306,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585306/inserting-file-into-blob-field-php-mysql-wont-accept-any-data-i-attempt-t',
#   'title': 'Inserting file into blob field [PHP] [mysql] - Won&#39;t accept any data I attempt to insert?'},
#  {'tags': ['azure', 'selenium-webdriver', 'azure-devops'],
#   'owner': {'account_id': 12608018,
#    'reputation': 1,
#    'user_id': 9168223,
#    'user_type': 'registered',
#    'profile_image': 'https://lh5.googleusercontent.com/-Q3GhRSF4u10/AAAAAAAAAAI/AAAAAAAABow/hi4SwAkiULk/photo.jpg?sz=256',
#    'display_name': 'Sridevi Srinivasan',
#    'link': 'https://stackoverflow.com/users/9168223/sridevi-srinivasan'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530108,
#   'creation_date': 1677530108,
#   'question_id': 75585305,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585305/where-in-azure-is-my-csv-error-files-from-the-application-are-stored-in-azure',
#   'title': 'Where in Azure is my .csv error files from the application are stored in Azure?'},
#  {'tags': ['java', 'docker', 'playwright-java'],
#   'owner': {'account_id': 10030252,
#    'reputation': 13,
#    'user_id': 19767912,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c1deaa774ac2c482d9f009cdf7b462a2?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user982455',
#    'link': 'https://stackoverflow.com/users/19767912/user982455'},
#   'is_answered': False,
#   'view_count': 35,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530107,
#   'creation_date': 1676589418,
#   'question_id': 75478872,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75478872/run-spring-boot-application-using-playwright-java-in-docker-container',
#   'title': 'Run Spring Boot application using Playwright Java in Docker container'},
#  {'tags': ['irc'],
#   'owner': {'account_id': 25892074,
#    'reputation': 1,
#    'user_id': 19619322,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/55Z5y.gif?s=256&g=1',
#    'display_name': 'JerryBerry12',
#    'link': 'https://stackoverflow.com/users/19619322/jerryberry12'},
#   'is_answered': False,
#   'view_count': 11,
#   'closed_date': 1677523406,
#   'answer_count': 0,
#   'score': -3,
#   'last_activity_date': 1677530107,
#   'creation_date': 1677522918,
#   'last_edit_date': 1677530107,
#   'question_id': 75584305,
#   'link': 'https://stackoverflow.com/questions/75584305/how-do-i-become-a-irc-netadmin',
#   'closed_reason': 'Not suitable for this site',
#   'title': 'How do I become a IRC NetAdmin?'},
#  {'tags': ['python', 'pandas', 'matplotlib', 'bar-chart'],
#   'owner': {'account_id': 23108188,
#    'reputation': 60,
#    'user_id': 17216471,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhzMVoSI4DhEnY8S_oCJe5rwkRh39ulkBpXd-iZQOo=k-s256',
#    'display_name': 'Colton Campbell',
#    'link': 'https://stackoverflow.com/users/17216471/colton-campbell'},
#   'is_answered': False,
#   'view_count': 9,
#   'closed_date': 1677530066,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530099,
#   'creation_date': 1677529339,
#   'question_id': 75585201,
#   'link': 'https://stackoverflow.com/questions/75585201/using-matplotlib-and-pandas-how-can-i-create-n-number-of-overlapping-bar-charts',
#   'closed_reason': 'Duplicate',
#   'title': 'Using Matplotlib and Pandas, how can I create n-number of overlapping bar charts with n-number of overlapping axes?'},
#  {'tags': ['c++'],
#   'owner': {'account_id': 3916521,
#    'reputation': 31,
#    'user_id': 3240228,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user3240228',
#    'link': 'https://stackoverflow.com/users/3240228/user3240228'},
#   'is_answered': False,
#   'view_count': 48,
#   'answer_count': 1,
#   'score': 2,
#   'last_activity_date': 1677530098,
#   'creation_date': 1677523422,
#   'last_edit_date': 1677530098,
#   'question_id': 75584381,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584381/c-cannot-pass-string-literal-const-char-to-a-function-with-parameter-type',
#   'title': 'C++ Cannot pass string literal &#39;const char []&#39; to a function with parameter type &#39;const T&amp;&#39; where T is typedef of char[]'},
#  {'tags': ['scala', 'haskell', 'types'],
#   'owner': {'account_id': 370114,
#    'reputation': 2134,
#    'user_id': 717858,
#    'user_type': 'registered',
#    'accept_rate': 86,
#    'profile_image': 'https://i.stack.imgur.com/ewjPh.jpg?s=256&g=1',
#    'display_name': 'Todd O&#39;Bryan',
#    'link': 'https://stackoverflow.com/users/717858/todd-obryan'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530091,
#   'creation_date': 1677530091,
#   'question_id': 75585304,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585304/scala-equivalent-of-haskell-type-constructor-inverse',
#   'title': 'Scala equivalent of Haskell type constructor/inverse?'},
#  {'tags': ['aws-lambda', 'aws-api-gateway', 'aws-cdk', 'aws-cdk-typescript'],
#   'owner': {'account_id': 2793197,
#    'reputation': 285,
#    'user_id': 2403018,
#    'user_type': 'registered',
#    'accept_rate': 25,
#    'profile_image': 'https://www.gravatar.com/avatar/222b5d55e427f25099151d25adf105d2?s=256&d=identicon&r=PG',
#    'display_name': 'user2403018',
#    'link': 'https://stackoverflow.com/users/2403018/user2403018'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530078,
#   'creation_date': 1677530078,
#   'question_id': 75585303,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585303/template-openapi-template-for-aws-apigateway-specrestapi-from-another-stack',
#   'title': 'Template openapi template for aws_apigateway.SpecRestApi from another stack'},
#  {'tags': ['c++', 'c', 'printing', 'floating-point', 'formatting'],
#   'owner': {'account_id': 2213450,
#    'reputation': 3667,
#    'user_id': 1954677,
#    'user_type': 'registered',
#    'accept_rate': 61,
#    'profile_image': 'https://www.gravatar.com/avatar/c95604a787536a0cfd261da70adb0e09?s=256&d=identicon&r=PG',
#    'display_name': 'flonk',
#    'link': 'https://stackoverflow.com/users/1954677/flonk'},
#   'is_answered': False,
#   'view_count': 74,
#   'answer_count': 3,
#   'score': 3,
#   'last_activity_date': 1677530076,
#   'creation_date': 1677494025,
#   'last_edit_date': 1677524571,
#   'question_id': 75579337,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75579337/how-to-use-c-c-format-specifiers-to-achieve-the-same-as-g-but-with-1-inst',
#   'title': 'How to use C/C++ format specifiers to achieve the same as &quot;g&quot; but with &quot;1.&quot; instead of &quot;1.0&quot;'},
#  {'tags': ['reactjs', 'firebase', 'react-native', 'expo'],
#   'owner': {'account_id': 20399957,
#    'reputation': 512,
#    'user_id': 14965903,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-v_Y_3faTBjw/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmgPBmjFnYxdF3BoI1-THONgrMfJQ/s96-c/photo.jpg?sz=256',
#    'display_name': 'newbie coder',
#    'link': 'https://stackoverflow.com/users/14965903/newbie-coder'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530072,
#   'creation_date': 1677526145,
#   'question_id': 75584771,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584771/upgrading-expo-can-not-start-because-of-the-issue-with-asyncstorage-and-firebase',
#   'title': 'Upgrading expo can not start because of the issue with AsyncStorage and firebase auth'},
#  {'tags': ['javascript', 'html', 'css'],
#   'owner': {'account_id': 27871532,
#    'reputation': 13,
#    'user_id': 21281950,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYXyS2ABsXqXHQpfiRN4GfDpdmfKY3N2IGdsJtt=k-s256',
#    'display_name': 'jhon barns',
#    'link': 'https://stackoverflow.com/users/21281950/jhon-barns'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530066,
#   'creation_date': 1677529675,
#   'last_edit_date': 1677530066,
#   'question_id': 75585245,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585245/how-to-resize-a-css-button-and-keep-the-inner-image-to-fit',
#   'title': 'How to resize a css button and keep the inner image to fit?'},
#  {'tags': ['c++'],
#   'owner': {'account_id': 1416313,
#    'reputation': 3812,
#    'user_id': 1341921,
#    'user_type': 'registered',
#    'accept_rate': 77,
#    'profile_image': 'https://www.gravatar.com/avatar/c149b4e22dece7405c2c85b74af18b57?s=256&d=identicon&r=PG',
#    'display_name': 'pmoubed',
#    'link': 'https://stackoverflow.com/users/1341921/pmoubed'},
#   'is_answered': True,
#   'view_count': 56,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1677530053,
#   'creation_date': 1677526197,
#   'last_edit_date': 1677529077,
#   'question_id': 75584779,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584779/is-this-pointer-valid-during-data-member-destruction',
#   'title': 'Is &quot;this&quot; pointer valid during data member destruction?'},
#  {'tags': ['routes', 'asp.net-core-mvc', 'cookie-authentication'],
#   'owner': {'account_id': 4352277,
#    'reputation': 13,
#    'user_id': 3552172,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user3552172',
#    'link': 'https://stackoverflow.com/users/3552172/user3552172'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530051,
#   'creation_date': 1677525777,
#   'last_edit_date': 1677530051,
#   'question_id': 75584724,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584724/asp-net-core-incorrect-route-for-loginpath',
#   'title': 'ASP.NET Core Incorrect Route for LoginPath'},
#  {'tags': ['python', 'pandas', 'tensorflow', 'pickle', 'fastapi'],
#   'owner': {'account_id': 19182486,
#    'reputation': 57,
#    'user_id': 14013882,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/e342794f63a1fa02acd7229bed658b81?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'gmelgkermglermgmrelkgm',
#    'link': 'https://stackoverflow.com/users/14013882/gmelgkermglermgmrelkgm'},
#   'is_answered': False,
#   'view_count': 54,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530049,
#   'creation_date': 1673909253,
#   'last_edit_date': 1673978521,
#   'question_id': 75140407,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75140407/dictionary-update-sequence-error-with-tensorflow-fastapi',
#   'title': 'Dictionary Update Sequence Error with Tensorflow + FastAPI'},
#  {'tags': ['pandas', 'dataframe'],
#   'owner': {'account_id': 25553802,
#    'reputation': 13,
#    'user_id': 19337723,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJx2n5DD9v8pES8u7MT9_xvN7evqWjI-z8wXIPG4=k-s256',
#    'display_name': 'M Kravets',
#    'link': 'https://stackoverflow.com/users/19337723/m-kravets'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530046,
#   'creation_date': 1677529902,
#   'question_id': 75585283,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585283/dataframe-merging-with-replacing-value',
#   'title': 'DataFrame merging with replacing value'},
#  {'tags': ['shell', 'unix'],
#   'owner': {'account_id': 10013677,
#    'reputation': 47,
#    'user_id': 7405752,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/9ca2e32f852a8fd34ee087bc47212717?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'AKPuvvada',
#    'link': 'https://stackoverflow.com/users/7405752/akpuvvada'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530045,
#   'creation_date': 1677530045,
#   'question_id': 75585298,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585298/mail-not-working-in-script-same-way-it-is-working-from-command-line',
#   'title': '&#39;mail&#39; not working in Script same way it is working from command line'},
#  {'tags': ['python', 'pandas', 'warnings', 'future', 'series'],
#   'owner': {'account_id': 27894134,
#    'reputation': 1,
#    'user_id': 21299829,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYHKf-fKFPkOwFydtuyk3WwuLQQfuOnwvCeGIOG=k-s256',
#    'display_name': 'Trevor Noah',
#    'link': 'https://stackoverflow.com/users/21299829/trevor-noah'},
#   'is_answered': False,
#   'view_count': 18,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1677530044,
#   'creation_date': 1677528222,
#   'last_edit_date': 1677530044,
#   'question_id': 75585066,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585066/futurewarning-the-default-dtype-for-empty-series-will-be-object-instead-of-f',
#   'title': 'FutureWarning: The default dtype for empty Series will be &#39;object&#39; instead of &#39;float64&#39; in a future version'},
#  {'tags': ['java', 'split', 'tokenize'],
#   'owner': {'account_id': 22962500,
#    'reputation': 1,
#    'user_id': 17092122,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/AvOav.jpg?s=256&g=1',
#    'display_name': 'Julia',
#    'link': 'https://stackoverflow.com/users/17092122/julia'},
#   'is_answered': False,
#   'view_count': 27,
#   'closed_date': 1677529080,
#   'answer_count': 1,
#   'score': -1,
#   'last_activity_date': 1677530044,
#   'creation_date': 1677528616,
#   'last_edit_date': 1677529083,
#   'question_id': 75585118,
#   'link': 'https://stackoverflow.com/questions/75585118/tokenize-the-string',
#   'closed_reason': 'Duplicate',
#   'title': 'Tokenize the string'},
#  {'tags': ['c#',
#    'arrays',
#    'memory-management',
#    'out-of-memory',
#    'floyd-warshall'],
#   'owner': {'account_id': 5370447,
#    'reputation': 15551,
#    'user_id': 4279155,
#    'user_type': 'registered',
#    'accept_rate': 55,
#    'profile_image': 'https://i.stack.imgur.com/Gve3F.png?s=256&g=1',
#    'display_name': 'Dominique',
#    'link': 'https://stackoverflow.com/users/4279155/dominique'},
#   'is_answered': False,
#   'view_count': 159,
#   'bounty_amount': 200,
#   'bounty_closes_date': 1677762141,
#   'answer_count': 1,
#   'score': 2,
#   'last_activity_date': 1677530043,
#   'creation_date': 1675179537,
#   'last_edit_date': 1677228153,
#   'question_id': 75299523,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75299523/how-to-handle-arrays-of-extremely-large-strings-in-c',
#   'title': 'How to handle arrays of extremely large strings in C#'},
#  {'tags': ['flutter', 'dart'],
#   'owner': {'account_id': 13727122,
#    'reputation': 337,
#    'user_id': 9905602,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/YBDjb.jpg?s=256&g=1',
#    'display_name': 'Giuseppe Cianci',
#    'link': 'https://stackoverflow.com/users/9905602/giuseppe-cianci'},
#   'is_answered': True,
#   'view_count': 882,
#   'accepted_answer_id': 70963189,
#   'answer_count': 1,
#   'score': 3,
#   'last_activity_date': 1677530030,
#   'creation_date': 1643818804,
#   'last_edit_date': 1643871563,
#   'question_id': 70959115,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/70959115/difference-between-casting-with-cast-method-and-as-keyword',
#   'title': 'Difference between casting with &#39;cast&#39; method and &#39;as&#39; keyword'},
#  {'tags': ['javascript', 'async-await', 'axios'],
#   'owner': {'account_id': 27894334,
#    'reputation': 1,
#    'user_id': 21299974,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxZJWsBLKZfQNKgAgMfhpIkiFAwAsBizwI9M8gri=k-s256',
#    'display_name': 'hori',
#    'link': 'https://stackoverflow.com/users/21299974/hori'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677530025,
#   'creation_date': 1677530025,
#   'question_id': 75585296,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75585296/how-can-it-be-undefined',
#   'title': 'How can it be undefined?'},
#  {'tags': ['rust', 'types'],
#   'owner': {'account_id': 18618506,
#    'reputation': 320,
#    'user_id': 13575954,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/DjxtL.jpg?s=256&g=1',
#    'display_name': 'kalkronline',
#    'link': 'https://stackoverflow.com/users/13575954/kalkronline'},
#   'is_answered': True,
#   'view_count': 16,
#   'accepted_answer_id': 75584111,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677530011,
#   'creation_date': 1677521426,
#   'question_id': 75584067,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75584067/how-to-specify-the-unused-return-type-of-a-generic-function',
#   'title': 'How to Specify the Unused Return Type of a Generic Function?'}]

# %% [markdown]
# ### access each question & it's links from the stack overflow

# %%
for data in response.json()["items"]:
    print(data["title"])
    print(data["link"])
    print()
# Out:
# I am looking for the regex (JavaScript) to grab any numbers that appear within a bracket
# https://stackoverflow.com/questions/75585301/i-am-looking-for-the-regex-javascript-to-grab-any-numbers-that-appear-within-a
#
# Difference between Application Documents Directory and Support Directory in path_provider?
# https://stackoverflow.com/questions/73685676/difference-between-application-documents-directory-and-support-directory-in-path
#
# Problem when trying to push files to from vs code to github repo
# https://stackoverflow.com/questions/75585310/problem-when-trying-to-push-files-to-from-vs-code-to-github-repo
#
# asp net session state redis cache managed identity or securing accessKey
# https://stackoverflow.com/questions/75585309/asp-net-session-state-redis-cache-managed-identity-or-securing-accesskey
#
# login authentification in c
# https://stackoverflow.com/questions/75584947/login-authentification-in-c
#
# Temporary table is not getting created inside Function in postgres
# https://stackoverflow.com/questions/75584642/temporary-table-is-not-getting-created-inside-function-in-postgres
#
# How do I group answers in categories JavaScript?
# https://stackoverflow.com/questions/49232478/how-do-i-group-answers-in-categories-javascript
#
# How to search and delete specific lines from a parquet file in pyspark? (data purge)
# https://stackoverflow.com/questions/75584567/how-to-search-and-delete-specific-lines-from-a-parquet-file-in-pyspark-data-pu
#
# Inserting file into blob field [PHP] [mysql] - Won&#39;t accept any data I attempt to insert?
# https://stackoverflow.com/questions/75585306/inserting-file-into-blob-field-php-mysql-wont-accept-any-data-i-attempt-t
#
# Where in Azure is my .csv error files from the application are stored in Azure?
# https://stackoverflow.com/questions/75585305/where-in-azure-is-my-csv-error-files-from-the-application-are-stored-in-azure
#
# Run Spring Boot application using Playwright Java in Docker container
# https://stackoverflow.com/questions/75478872/run-spring-boot-application-using-playwright-java-in-docker-container
#
# How do I become a IRC NetAdmin?
# https://stackoverflow.com/questions/75584305/how-do-i-become-a-irc-netadmin
#
# Using Matplotlib and Pandas, how can I create n-number of overlapping bar charts with n-number of overlapping axes?
# https://stackoverflow.com/questions/75585201/using-matplotlib-and-pandas-how-can-i-create-n-number-of-overlapping-bar-charts
#
# C++ Cannot pass string literal &#39;const char []&#39; to a function with parameter type &#39;const T&amp;&#39; where T is typedef of char[]
# https://stackoverflow.com/questions/75584381/c-cannot-pass-string-literal-const-char-to-a-function-with-parameter-type
#
# Scala equivalent of Haskell type constructor/inverse?
# https://stackoverflow.com/questions/75585304/scala-equivalent-of-haskell-type-constructor-inverse
#
# Template openapi template for aws_apigateway.SpecRestApi from another stack
# https://stackoverflow.com/questions/75585303/template-openapi-template-for-aws-apigateway-specrestapi-from-another-stack
#
# How to use C/C++ format specifiers to achieve the same as &quot;g&quot; but with &quot;1.&quot; instead of &quot;1.0&quot;
# https://stackoverflow.com/questions/75579337/how-to-use-c-c-format-specifiers-to-achieve-the-same-as-g-but-with-1-inst
#
# Upgrading expo can not start because of the issue with AsyncStorage and firebase auth
# https://stackoverflow.com/questions/75584771/upgrading-expo-can-not-start-because-of-the-issue-with-asyncstorage-and-firebase
#
# How to resize a css button and keep the inner image to fit?
# https://stackoverflow.com/questions/75585245/how-to-resize-a-css-button-and-keep-the-inner-image-to-fit
#
# Is &quot;this&quot; pointer valid during data member destruction?
# https://stackoverflow.com/questions/75584779/is-this-pointer-valid-during-data-member-destruction
#
# ASP.NET Core Incorrect Route for LoginPath
# https://stackoverflow.com/questions/75584724/asp-net-core-incorrect-route-for-loginpath
#
# Dictionary Update Sequence Error with Tensorflow + FastAPI
# https://stackoverflow.com/questions/75140407/dictionary-update-sequence-error-with-tensorflow-fastapi
#
# DataFrame merging with replacing value
# https://stackoverflow.com/questions/75585283/dataframe-merging-with-replacing-value
#
# &#39;mail&#39; not working in Script same way it is working from command line
# https://stackoverflow.com/questions/75585298/mail-not-working-in-script-same-way-it-is-working-from-command-line
#
# FutureWarning: The default dtype for empty Series will be &#39;object&#39; instead of &#39;float64&#39; in a future version
# https://stackoverflow.com/questions/75585066/futurewarning-the-default-dtype-for-empty-series-will-be-object-instead-of-f
#
# Tokenize the string
# https://stackoverflow.com/questions/75585118/tokenize-the-string
#
# How to handle arrays of extremely large strings in C#
# https://stackoverflow.com/questions/75299523/how-to-handle-arrays-of-extremely-large-strings-in-c
#
# Difference between casting with &#39;cast&#39; method and &#39;as&#39; keyword
# https://stackoverflow.com/questions/70959115/difference-between-casting-with-cast-method-and-as-keyword
#
# How can it be undefined?
# https://stackoverflow.com/questions/75585296/how-can-it-be-undefined
#
# How to Specify the Unused Return Type of a Generic Function?
# https://stackoverflow.com/questions/75584067/how-to-specify-the-unused-return-type-of-a-generic-function

# %% [markdown]
# ### find questions and it's links that are not answered

# %%
for data in response.json()["items"]:
    if data["answer_count"] == 0:
        print(data["title"])
        print(data["link"])
    else:
        print("Skipped")
    print()
# Out:
# I am looking for the regex (JavaScript) to grab any numbers that appear within a bracket
# https://stackoverflow.com/questions/75585301/i-am-looking-for-the-regex-javascript-to-grab-any-numbers-that-appear-within-a
#
# Skipped
#
# Problem when trying to push files to from vs code to github repo
# https://stackoverflow.com/questions/75585310/problem-when-trying-to-push-files-to-from-vs-code-to-github-repo
#
# asp net session state redis cache managed identity or securing accessKey
# https://stackoverflow.com/questions/75585309/asp-net-session-state-redis-cache-managed-identity-or-securing-accesskey
#
# Skipped
#
# Temporary table is not getting created inside Function in postgres
# https://stackoverflow.com/questions/75584642/temporary-table-is-not-getting-created-inside-function-in-postgres
#
# Skipped
#
# Skipped
#
# Inserting file into blob field [PHP] [mysql] - Won&#39;t accept any data I attempt to insert?
# https://stackoverflow.com/questions/75585306/inserting-file-into-blob-field-php-mysql-wont-accept-any-data-i-attempt-t
#
# Where in Azure is my .csv error files from the application are stored in Azure?
# https://stackoverflow.com/questions/75585305/where-in-azure-is-my-csv-error-files-from-the-application-are-stored-in-azure
#
# Skipped
#
# How do I become a IRC NetAdmin?
# https://stackoverflow.com/questions/75584305/how-do-i-become-a-irc-netadmin
#
# Using Matplotlib and Pandas, how can I create n-number of overlapping bar charts with n-number of overlapping axes?
# https://stackoverflow.com/questions/75585201/using-matplotlib-and-pandas-how-can-i-create-n-number-of-overlapping-bar-charts
#
# Skipped
#
# Scala equivalent of Haskell type constructor/inverse?
# https://stackoverflow.com/questions/75585304/scala-equivalent-of-haskell-type-constructor-inverse
#
# Template openapi template for aws_apigateway.SpecRestApi from another stack
# https://stackoverflow.com/questions/75585303/template-openapi-template-for-aws-apigateway-specrestapi-from-another-stack
#
# Skipped
#
# Skipped
#
# How to resize a css button and keep the inner image to fit?
# https://stackoverflow.com/questions/75585245/how-to-resize-a-css-button-and-keep-the-inner-image-to-fit
#
# Skipped
#
# ASP.NET Core Incorrect Route for LoginPath
# https://stackoverflow.com/questions/75584724/asp-net-core-incorrect-route-for-loginpath
#
# Skipped
#
# Skipped
#
# &#39;mail&#39; not working in Script same way it is working from command line
# https://stackoverflow.com/questions/75585298/mail-not-working-in-script-same-way-it-is-working-from-command-line
#
# Skipped
#
# Skipped
#
# Skipped
#
# Skipped
#
# How can it be undefined?
# https://stackoverflow.com/questions/75585296/how-can-it-be-undefined
#
# Skipped

# %% [markdown]
# ## Consuming REST COUNTRIES API

# %%
# import library
import pandas
import requests
import json

# %%
response = requests.get("https://restcountries.com/v3.1/all")

# %%
response.json()[4]
# Out:
# {'name': {'common': 'Wallis and Futuna',
#   'official': 'Territory of the Wallis and Futuna Islands',
#   'nativeName': {'fra': {'official': 'Territoire des îles Wallis et Futuna',
#     'common': 'Wallis et Futuna'}}},
#  'tld': ['.wf'],
#  'cca2': 'WF',
#  'ccn3': '876',
#  'cca3': 'WLF',
#  'independent': False,
#  'status': 'officially-assigned',
#  'unMember': False,
#  'currencies': {'XPF': {'name': 'CFP franc', 'symbol': '₣'}},
#  'idd': {'root': '+6', 'suffixes': ['81']},
#  'capital': ['Mata-Utu'],
#  'altSpellings': ['WF',
#   'Territory of the Wallis and Futuna Islands',
#   'Territoire des îles Wallis et Futuna'],
#  'region': 'Oceania',
#  'subregion': 'Polynesia',
#  'languages': {'fra': 'French'},
#  'translations': {'ara': {'official': 'إقليم جزر واليس وفوتونا',
#    'common': 'واليس وفوتونا'},
#   'bre': {'official': 'Tiriad Inizi Wallis ha Futuna',
#    'common': 'Wallis ha Futuna'},
#   'ces': {'official': 'Teritorium ostrovů Wallis a Futuna',
#    'common': 'Wallis a Futuna'},
#   'cym': {'official': 'Territory of the Wallis and Futuna Islands',
#    'common': 'Wallis and Futuna'},
#   'deu': {'official': 'Gebiet der Wallis und Futuna',
#    'common': 'Wallis und Futuna'},
#   'est': {'official': 'Wallise ja Futuna ala', 'common': 'Wallis ja Futuna'},
#   'fin': {'official': 'Wallisin ja Futunan yhteisö',
#    'common': 'Wallis ja Futuna'},
#   'fra': {'official': 'Territoire des îles Wallis et Futuna',
#    'common': 'Wallis-et-Futuna'},
#   'hrv': {'official': 'Teritoriju Wallis i Futuna',
#    'common': 'Wallis i Fortuna'},
#   'hun': {'official': 'Wallis és Futuna', 'common': 'Wallis és Futuna'},
#   'ita': {'official': 'Territorio delle Isole Wallis e Futuna',
#    'common': 'Wallis e Futuna'},
#   'jpn': {'official': 'ウォリス·フツナ諸島の領土', 'common': 'ウォリス・フツナ'},
#   'kor': {'official': '왈리스 퓌튀나', 'common': '왈리스 퓌튀나'},
#   'nld': {'official': 'Grondgebied van de Wallis en Futuna',
#    'common': 'Wallis en Futuna'},
#   'per': {'official': 'جزایر والیس و فوتونا', 'common': 'والیس و فوتونا'},
#   'pol': {'official': 'Terytorium Wysp Wallis i Futuna',
#    'common': 'Wallis i Futuna'},
#   'por': {'official': 'Território das Ilhas Wallis e Futuna',
#    'common': 'Wallis e Futuna'},
#   'rus': {'official': 'Территория Уоллис и Футуна острова',
#    'common': 'Уоллис и Футуна'},
#   'slk': {'official': 'Teritórium ostrovov Wallis a Futuna',
#    'common': 'Wallis a Futuna'},
#   'spa': {'official': 'Territorio de las Islas Wallis y Futuna',
#    'common': 'Wallis y Futuna'},
#   'srp': {'official': 'Територија државе Валис и Футуна',
#    'common': 'Валис и Футуна'},
#   'swe': {'official': 'Territoriet Wallis- och Futunaöarna',
#    'common': 'Wallis- och Futunaöarna'},
#   'tur': {'official': 'Wallis ve Futuna Adaları Bölgesi',
#    'common': 'Wallis ve Futuna Adaları Bölgesi'},
#   'urd': {'official': 'سر زمینِ والس و فتونہ جزائر', 'common': 'والس و فتونہ'},
#   'zho': {'official': '瓦利斯和富图纳群岛', 'common': '瓦利斯和富图纳群岛'}},
#  'latlng': [-13.3, -176.2],
#  'landlocked': False,
#  'area': 142.0,
#  'demonyms': {'eng': {'f': 'Wallis and Futuna Islander',
#    'm': 'Wallis and Futuna Islander'}},
#  'flag': '🇼🇫',
#  'maps': {'googleMaps': 'https://goo.gl/maps/CzVqK74QYtbHv65r5',
#   'openStreetMaps': 'https://www.openstreetmap.org/relation/3412448'},
#  'population': 11750,
#  'car': {'signs': ['F'], 'side': 'right'},
#  'timezones': ['UTC+12:00'],
#  'continents': ['Oceania'],
#  'flags': {'png': 'https://flagcdn.com/w320/wf.png',
#   'svg': 'https://flagcdn.com/wf.svg'},
#  'coatOfArms': {},
#  'startOfWeek': 'monday',
#  'capitalInfo': {'latlng': [-13.95, -171.93]},
#  'postalCode': {'format': '#####', 'regex': '^(986\\d{2})$'}}

# %%
for data in response.json()[0]:
    print(data)
# Out:
# name
# tld
# cca2
# ccn3
# cca3
# cioc
# independent
# status
# unMember
# currencies
# idd
# capital
# altSpellings
# region
# subregion
# languages
# translations
# latlng
# landlocked
# borders
# area
# demonyms
# flag
# maps
# population
# fifa
# car
# timezones
# continents
# flags
# coatOfArms
# startOfWeek
# capitalInfo
# postalCode
