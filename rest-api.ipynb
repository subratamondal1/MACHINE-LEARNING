# %% [markdown]
# <a href="https://www.kaggle.com/code/subratasubha/create-datasets-using-rest-api?scriptVersionId=120896957" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # <center>REST API</center>
# ---

# %% [markdown]
# ## Overview
# Application Programming Iterface (API) it's basically a fancy way of saying that it's a way two pieces of software interact with ome another, no matter in which programming language both the softwares were created.
#
# * **REST API:** A REST API is an application programming interface that follows the principles of REST (REpresentational State Transfer), an architectural style for creating web services. A REST API allows different applications or devices to communicate with each other using standard methods like GET, POST, PUT and DELETE.
#
# * **JSON:** JSON (JavaScript Object Notation) is a data format that is commonly used by REST APIs to exchange information between a client and a server. A REST API can use different data formats to transfer information between the client and the server, but JSON is preferred by many developers because it is lightweight and easy to parse.
#
# * **Endpoint:** An endpoint is a URL that defines how a client can access a resource or perform an operation on that resource using HTTP methods. For example, `https://mydomain/user/123?format=json` is an endpoint that returns the user with id 123 in JSON format. A REST API should use nouns instead of verbs in the endpoints to indicate what each of them does. For example, **GET** /users should return all users, **POST** /users should create a new user, **PUT** /users/123 should update user 123, and **DELETE** /users/123 should delete user 123
#
# ## Some of the benefits of using REST APIs are:
#
# * They are lightweight and fast, because they rely on the HTTP standard and can use different data formats such as JSON, XML, HTML, etc.
# * They are independent and decoupled, because they separate the data storage and the UI from the server. This means that developers can work on different parts of a project independently and try out multiple environments as needed.
# * They are scalable and flexible, because they can handle different types of requests and responses using HTTP methods. This also makes them easier to cache and reuse.

# %% [markdown]
# ## Consuming Stackoverflow's Rest Api

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json

# %% [markdown]
# ### make a request to any page

# %%
# make a request to any page
requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
# Out:
# <Response [200]>

# %%
# store the response
response = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### access the data returned to response in json format

# %%
# returns all the data that we have got if we request in a web browser or in postman
response.json()
# Out:
# {'items': [{'tags': ['php', 'laravel-8'],
#    'owner': {'account_id': 25861966,
#     'reputation': 21,
#     'user_id': 19594303,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmmk72o3opmAUezlKzPc87C4qk1zBsEmzQw1VScW=k-s256',
#     'display_name': 'mohit baraiya',
#     'link': 'https://stackoverflow.com/users/19594303/mohit-baraiya'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814887,
#    'creation_date': 1677814887,
#    'question_id': 75622977,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622977/how-to-group-route-by-name-in-laravel',
#    'title': 'how to group route by name in laravel'},
#   {'tags': ['amazon-ec2', 'terraform', 'datasource', 'private-subnet'],
#    'owner': {'account_id': 16304895,
#     'reputation': 11,
#     'user_id': 19533919,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d768746905fca7b8715396fda9cc239a?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Sanjeev',
#     'link': 'https://stackoverflow.com/users/19533919/sanjeev'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814886,
#    'creation_date': 1677813845,
#    'last_edit_date': 1677814886,
#    'question_id': 75622895,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622895/how-to-call-subnet-id-from-data-source-when-i-am-creating-ec2-instance-and-sg',
#    'title': 'How to call subnet id from data source , when i am creating ec2 instance and sg in existing vpc via terraform'},
#   {'tags': ['php', 'permissions', 'ftp'],
#    'owner': {'account_id': 27828749,
#     'reputation': 1,
#     'user_id': 21247590,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6c433581002eddb861c24e4559428683?s=256&d=identicon&r=PG',
#     'display_name': 'Glenn',
#     'link': 'https://stackoverflow.com/users/21247590/glenn'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814878,
#    'creation_date': 1677814878,
#    'question_id': 75622976,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622976/php-ftp-ftp-mkdir-fails-without-any-error-message',
#    'title': 'PHP FTP - ftp_mkdir fails without any error message'},
#   {'tags': ['java', 'database', 'hibernate', 'intellij-idea', 'dbeaver'],
#    'owner': {'account_id': 26964597,
#     'reputation': 1,
#     'user_id': 20531706,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/ALm5wu0t3hh-kKaJq6x9c-10iZY94ktc8wVxir2USuFm=k-s256',
#     'display_name': 'Nikita Parsons',
#     'link': 'https://stackoverflow.com/users/20531706/nikita-parsons'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814875,
#    'creation_date': 1677751849,
#    'last_edit_date': 1677814875,
#    'question_id': 75613980,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75613980/trying-to-connect-a-dbeaver-database-to-intellij',
#    'title': 'Trying to connect a dbeaver database to intellij'},
#   {'tags': ['php', 'mysql'],
#    'owner': {'account_id': 27923138,
#     'reputation': 1,
#     'user_id': 21322784,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYsvPvrzEDV2AJRvRoLfGoWPc6DtCo78w21BRcH=k-s256',
#     'display_name': 'Jordan Rosel',
#     'link': 'https://stackoverflow.com/users/21322784/jordan-rosel'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814875,
#    'creation_date': 1677809684,
#    'last_edit_date': 1677814875,
#    'question_id': 75622604,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622604/how-to-boost-my-mysql-datetime-query-with-thousands-of-rows',
#    'title': 'How to boost my Mysql datetime query with thousands of rows'},
#   {'tags': ['html', 'css'],
#    'owner': {'account_id': 24136874,
#     'reputation': 59,
#     'user_id': 18103650,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4d0271c5d262ade03e371672d521ab91?s=256&d=identicon&r=PG',
#     'display_name': 'Laplas',
#     'link': 'https://stackoverflow.com/users/18103650/laplas'},
#    'is_answered': False,
#    'view_count': 24,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677814875,
#    'creation_date': 1677774261,
#    'question_id': 75618213,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75618213/how-fix-broken-text-in-my-menu-and-broken-img',
#    'title': 'How fix broken text in my menu and broken img'},
#   {'tags': ['javascript', 'html', 'css', 'toggle', 'display'],
#    'owner': {'account_id': 27923675,
#     'reputation': 1,
#     'user_id': 21323223,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYzzKHVlkKLmIhqKZ3ac9cuv0N2pyau0OpVJre3Zw=k-s256',
#     'display_name': 'Rathan Raju',
#     'link': 'https://stackoverflow.com/users/21323223/rathan-raju'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814867,
#    'creation_date': 1677814867,
#    'question_id': 75622974,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622974/toggle-display-with-javascript',
#    'title': 'toggle display with javascript'},
#   {'tags': ['r', 'database', 'dataframe', 'dplyr', 'grouping'],
#    'owner': {'account_id': 23991396,
#     'reputation': 69,
#     'user_id': 17977503,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gi_TgCyQRKlQ3bSU-vZB0PvHnKr8h3OOsZX80QD2Q=k-s256',
#     'display_name': 'Marnee Roundtree',
#     'link': 'https://stackoverflow.com/users/17977503/marnee-roundtree'},
#    'is_answered': True,
#    'view_count': 22,
#    'accepted_answer_id': 75622601,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1677814859,
#    'creation_date': 1677809067,
#    'last_edit_date': 1677809676,
#    'question_id': 75622561,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622561/r-grouping-character-data-into-numeric',
#    'title': 'R - Grouping character data into numeric'},
#   {'tags': ['c#',
#     'azure',
#     'asp.net-core',
#     'azure-authentication',
#     'blazor-hybrid'],
#    'owner': {'account_id': 17003522,
#     'reputation': 1471,
#     'user_id': 12300287,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/v8TOr.jpg?s=256&g=1',
#     'display_name': 'Lukas',
#     'link': 'https://stackoverflow.com/users/12300287/lukas'},
#    'is_answered': False,
#    'view_count': 17,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677814856,
#    'creation_date': 1677791126,
#    'question_id': 75620820,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75620820/how-to-implement-sign-in-with-azure-ad-in-a-blazor-hybrid-application',
#    'title': 'How to implement sign-in with Azure AD in a Blazor Hybrid application?'},
#   {'tags': ['performance',
#     'testing',
#     'automation',
#     'correlation',
#     'loadrunner'],
#    'owner': {'account_id': 24888610,
#     'reputation': 21,
#     'user_id': 18760894,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/fc5908bc93272821ecfe63ee52743214?s=256&d=identicon&r=PG',
#     'display_name': 'afirdaus04',
#     'link': 'https://stackoverflow.com/users/18760894/afirdaus04'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814855,
#    'creation_date': 1677814855,
#    'question_id': 75622971,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622971/is-it-possible-to-correlate-specific-id-using-loadrunner',
#    'title': 'Is it possible to correlate specific ID using Loadrunner?'},
#   {'tags': ['node.js', 'puppeteer'],
#    'owner': {'account_id': 15569367,
#     'reputation': 125,
#     'user_id': 11232218,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-D_kNYBb45lE/AAAAAAAAAAI/AAAAAAAAIB0/UWPH_ViJjJs/photo.jpg?sz=256',
#     'display_name': 'Emmanuel Oliveira',
#     'link': 'https://stackoverflow.com/users/11232218/emmanuel-oliveira'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814850,
#    'creation_date': 1677814850,
#    'question_id': 75622970,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622970/there-is-a-way-to-import-nodejs-scripts-into-mabl-with-puppeteer',
#    'title': 'There is a way to import nodejs scripts into Mabl with puppeteer?'},
#   {'tags': ['javascript', 'arrays', 'multidimensional-array'],
#    'owner': {'account_id': 21555483,
#     'reputation': 1,
#     'user_id': 15890809,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/CdYYU.jpg?s=256&g=1',
#     'display_name': 'garikarta',
#     'link': 'https://stackoverflow.com/users/15890809/garikarta'},
#    'is_answered': False,
#    'view_count': 17,
#    'closed_date': 1677814594,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814850,
#    'creation_date': 1677813990,
#    'last_edit_date': 1677814850,
#    'question_id': 75622902,
#    'link': 'https://stackoverflow.com/questions/75622902/javascript-comparation-array',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'Javascript comparation array'},
#   {'tags': ['javascript', 'node.js', 'node-modules'],
#    'owner': {'account_id': 26762791,
#     'reputation': 1,
#     'user_id': 20360452,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5a2589719b002424b25eeb320077b81a?s=256&d=identicon&r=PG',
#     'display_name': 'Gabriel Oliveira',
#     'link': 'https://stackoverflow.com/users/20360452/gabriel-oliveira'},
#    'is_answered': False,
#    'view_count': 68,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1677814807,
#    'creation_date': 1666978597,
#    'question_id': 74239007,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74239007/start-a-puppetter-in-gitpod',
#    'title': 'Start a puppetter in gitpod'},
#   {'tags': ['javascript', 'google-apps-script', 'google-sheets'],
#    'owner': {'account_id': 16631003,
#     'reputation': 23,
#     'user_id': 12018855,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4427dab3bf6feacd9583324513e3f382?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'NestoJosa',
#     'link': 'https://stackoverflow.com/users/12018855/nestojosa'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814799,
#    'creation_date': 1677814122,
#    'last_edit_date': 1677814799,
#    'question_id': 75622916,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622916/how-to-add-automatically-add-a-formula-to-a-cell-of-a-newly-inserted-row',
#    'title': 'How to add automatically add a formula to a cell of a newly inserted row?'},
#   {'tags': ['angular', 'typescript', 'ionic-framework'],
#    'owner': {'account_id': 21903542,
#     'reputation': 93,
#     'user_id': 16188928,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgVFNa2VUFxGacn2DwEf5xig25cZiqOSRstTXOT_Q=k-s256',
#     'display_name': 'Steven',
#     'link': 'https://stackoverflow.com/users/16188928/steven'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814796,
#    'creation_date': 1677814796,
#    'question_id': 75622968,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622968/why-does-console-show-error-when-i-declare-datetime-in-ionic',
#    'title': 'why does console show error when I declare datetime in ionic'},
#   {'tags': ['google-chrome-extension', 'knockout.js'],
#    'owner': {'account_id': 27806745,
#     'reputation': 1,
#     'user_id': 21229978,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp4L3iLO5KMuzu8smyACCRxKybWYToKc3g36sqQG=k-s256',
#     'display_name': 'Franklin Tardencilla',
#     'link': 'https://stackoverflow.com/users/21229978/franklin-tardencilla'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814793,
#    'creation_date': 1677812717,
#    'last_edit_date': 1677814793,
#    'question_id': 75622821,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622821/how-to-update-knockout-js-input-field-from-content-script-on-chrome-extension',
#    'title': 'How to update knockout js input field from content script on Chrome extension?'},
#   {'tags': ['python', 'data-analysis'],
#    'owner': {'account_id': 20543617,
#     'reputation': 60,
#     'user_id': 15078021,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f28d235f944388b0a98633ff46880ac3?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Prima',
#     'link': 'https://stackoverflow.com/users/15078021/prima'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814774,
#    'creation_date': 1677814774,
#    'question_id': 75622967,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622967/how-to-find-peak-hours-transcation-using-group-by-in-python',
#    'title': 'how to find peak hours transcation using group by in python'},
#   {'tags': ['python', 'plotly'],
#    'owner': {'account_id': 17824149,
#     'reputation': 191,
#     'user_id': 12945785,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/10b08972868adf17bb7adfa40bcccbf9?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Jacques',
#     'link': 'https://stackoverflow.com/users/12945785/jacques'},
#    'is_answered': False,
#    'view_count': 17,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1677814772,
#    'creation_date': 1677764875,
#    'question_id': 75616311,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75616311/plotly-add-legend-in-hover-graph',
#    'title': 'Plotly add legend in hover graph'},
#   {'tags': ['sql', 'elixir', 'ecto'],
#    'owner': {'account_id': 20583504,
#     'reputation': 11,
#     'user_id': 15108984,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bcccce4e12789305975ac7945641f0ee?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Billbryson78',
#     'link': 'https://stackoverflow.com/users/15108984/billbryson78'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814771,
#    'creation_date': 1677814771,
#    'question_id': 75622965,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622965/dynamic-elixir-ecto-query',
#    'title': 'Dynamic Elixir Ecto Query'},
#   {'tags': ['javascript', 'vue.js', 'vuejs2', 'vue-component', 'vuejs3'],
#    'owner': {'account_id': 27638742,
#     'reputation': 1,
#     'user_id': 21096140,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp5mT6rhHUe7HzxgGgOaCpah2urXBnV7LhFeAHcj=k-s256',
#     'display_name': 'nataly ren',
#     'link': 'https://stackoverflow.com/users/21096140/nataly-ren'},
#    'is_answered': False,
#    'view_count': 88,
#    'answer_count': 3,
#    'score': 0,
#    'last_activity_date': 1677814768,
#    'creation_date': 1676898438,
#    'last_edit_date': 1676904607,
#    'question_id': 75509635,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75509635/nexttick-uses-in-vuejs-and-component-update',
#    'title': 'nextTick uses in vuejs and component update'},
#   {'tags': ['visual-studio-code'],
#    'owner': {'account_id': 27919330,
#     'reputation': 1,
#     'user_id': 21319842,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1a530a6b698d6d61abb1b8efef295b0b?s=256&d=identicon&r=PG',
#     'display_name': 'lichangwei',
#     'link': 'https://stackoverflow.com/users/21319842/lichangwei'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814767,
#    'creation_date': 1677814767,
#    'question_id': 75622964,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622964/build-vscode-why-packaging-software-date-error-please-help-why-1980',
#    'title': 'build vscode. Why packaging software date error, please help. Why 1980'},
#   {'tags': ['vue.js', 'vuejs3', 'vue-router'],
#    'owner': {'account_id': 550716,
#     'reputation': 3238,
#     'user_id': 160059,
#     'user_type': 'registered',
#     'accept_rate': 62,
#     'profile_image': 'https://www.gravatar.com/avatar/f1b7d5b19fd83b3ed1f91311ddfa9022?s=256&d=identicon&r=PG',
#     'display_name': 'rendom',
#     'link': 'https://stackoverflow.com/users/160059/rendom'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814753,
#    'creation_date': 1677814424,
#    'last_edit_date': 1677814753,
#    'question_id': 75622941,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622941/vue3-router-2-routers-with-different-history',
#    'title': 'vue3 router - 2 routers with different history'},
#   {'tags': ['swift', 'swiftui', 'swiftui-navigationlink'],
#    'owner': {'account_id': 27923695,
#     'reputation': 1,
#     'user_id': 21323238,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c67eeebb014e88975f606d8507bb4030?s=256&d=identicon&r=PG',
#     'display_name': 'WPD2050',
#     'link': 'https://stackoverflow.com/users/21323238/wpd2050'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814748,
#    'creation_date': 1677814748,
#    'question_id': 75622963,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622963/double-back-buttons-in-swift-nav-view',
#    'title': 'Double Back Buttons in Swift Nav View'},
#   {'tags': ['python-3.x', 'qt', 'thread-safety', 'pyside6'],
#    'owner': {'account_id': 4534975,
#     'reputation': 353,
#     'user_id': 3684433,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/a34CF.png?s=256&g=1',
#     'display_name': 'maldata',
#     'link': 'https://stackoverflow.com/users/3684433/maldata'},
#    'is_answered': True,
#    'view_count': 16,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1677814745,
#    'creation_date': 1677799850,
#    'question_id': 75621819,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75621819/how-to-manage-python-callbacks-executed-from-a-c-library-in-a-qt-pyside6-applica',
#    'title': 'How to manage python callbacks executed from a C library in a Qt/PySide6 application?'},
#   {'tags': ['sql', 'elasticsearch', 'grafana', 'opensearch'],
#    'owner': {'account_id': 3420730,
#     'reputation': 1255,
#     'user_id': 2868465,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://i.stack.imgur.com/VJ8Gy.jpg?s=256&g=1',
#     'display_name': 'rrlamichhane',
#     'link': 'https://stackoverflow.com/users/2868465/rrlamichhane'},
#    'is_answered': True,
#    'view_count': 15,
#    'accepted_answer_id': 75622774,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1677814738,
#    'creation_date': 1677162445,
#    'last_edit_date': 1677814738,
#    'question_id': 75546158,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75546158/how-to-configure-opensearch-elasticsearch-sql-plug-in-as-a-datasource-in-grafana',
#    'title': 'How to configure OpenSearch/ElasticSearch SQL plug-in as a datasource in Grafana?'},
#   {'tags': ['r', 'large-data', 'imbalanced-data', 'smote'],
#    'owner': {'account_id': 27923362,
#     'reputation': 1,
#     'user_id': 21322962,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c8e1d4b8a4faa93944e15bc26de3adba?s=256&d=identicon&r=PG',
#     'display_name': 'Surfer1560',
#     'link': 'https://stackoverflow.com/users/21322962/surfer1560'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814734,
#    'creation_date': 1677810980,
#    'last_edit_date': 1677814734,
#    'question_id': 75622692,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622692/themistomek-returning-0-observations',
#    'title': 'themis::tomek() returning 0 observations'},
#   {'tags': ['docker', 'kubernetes', 'containers', 'containerd', 'harbor'],
#    'owner': {'account_id': 24106733,
#     'reputation': 1,
#     'user_id': 18077825,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1787d1a6ddf124d44303dfce1c758931?s=256&d=identicon&r=PG',
#     'display_name': 'Prodigalgal',
#     'link': 'https://stackoverflow.com/users/18077825/prodigalgal'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814726,
#    'creation_date': 1677814588,
#    'last_edit_date': 1677814726,
#    'question_id': 75622952,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622952/failed-to-unpack-image-on-snapshotter-overlayfs-unexpected-media-type-text-html',
#    'title': 'failed to unpack image on snapshotter overlayfs: unexpected media type text/html'},
#   {'tags': ['admin', 'visual-studio-2022'],
#    'owner': {'account_id': 11724184,
#     'reputation': 35,
#     'user_id': 9878657,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0ec62cdd8e13e5cf6ccabef78ba4274d?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Paulo Eduardo Pilon',
#     'link': 'https://stackoverflow.com/users/9878657/paulo-eduardo-pilon'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 0,
#    'score': -2,
#    'last_activity_date': 1677814718,
#    'creation_date': 1677807048,
#    'last_edit_date': 1677814718,
#    'question_id': 75622415,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622415/visual-studio-2022-once-run-as-admin-never-goes-back-to-normal',
#    'title': 'Visual Studio 2022 once run as ADMIN never goes back to normal'},
#   {'tags': ['php', 'xml', 'php-8'],
#    'owner': {'account_id': 27923526,
#     'reputation': 1,
#     'user_id': 21323099,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3ebd8bf961241fd19ecad0ae9d923345?s=256&d=identicon&r=PG',
#     'display_name': 'fishman1019',
#     'link': 'https://stackoverflow.com/users/21323099/fishman1019'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1677814717,
#    'creation_date': 1677814717,
#    'question_id': 75622961,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75622961/why-did-php-8-break-my-foreach-loop-which-works-fine-in-php-7-4-and-before',
#    'title': 'Why did php 8 break my foreach loop which works fine in php 7.4 and before?'},
#   {'tags': ['python', 'python-3.x', 'multiprocessing', 'generator'],
#    'owner': {'account_id': 2410286,
#     'reputation': 317,
#     'user_id': 2105525,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.stack.imgur.com/2AGIx.png?s=256&g=1',
#     'display_name': 'Akababa',
#     'link': 'https://stackoverflow.com/users/2105525/akababa'},
#    'is_answered': True,
#    'view_count': 2135,
#    'accepted_answer_id': 48135880,
#    'answer_count': 2,
#    'score': 6,
#    'last_activity_date': 1677814716,
#    'creation_date': 1515311826,
#    'last_edit_date': 1515315836,
#    'question_id': 48135348,
#    'content_license': 'CC BY-SA 3.0',
#    'link': 'https://stackoverflow.com/questions/48135348/lazy-processpoolexecutor-in-python',
#    'title': 'lazy processpoolexecutor in Python?'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 298}

# %% [markdown]
# ### lets explore one of the elements of the response data

# %%
response.json()["items"]
# Out:
# [{'tags': ['php', 'laravel-8'],
#   'owner': {'account_id': 25861966,
#    'reputation': 21,
#    'user_id': 19594303,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmmk72o3opmAUezlKzPc87C4qk1zBsEmzQw1VScW=k-s256',
#    'display_name': 'mohit baraiya',
#    'link': 'https://stackoverflow.com/users/19594303/mohit-baraiya'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814887,
#   'creation_date': 1677814887,
#   'question_id': 75622977,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622977/how-to-group-route-by-name-in-laravel',
#   'title': 'how to group route by name in laravel'},
#  {'tags': ['amazon-ec2', 'terraform', 'datasource', 'private-subnet'],
#   'owner': {'account_id': 16304895,
#    'reputation': 11,
#    'user_id': 19533919,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/d768746905fca7b8715396fda9cc239a?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Sanjeev',
#    'link': 'https://stackoverflow.com/users/19533919/sanjeev'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814886,
#   'creation_date': 1677813845,
#   'last_edit_date': 1677814886,
#   'question_id': 75622895,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622895/how-to-call-subnet-id-from-data-source-when-i-am-creating-ec2-instance-and-sg',
#   'title': 'How to call subnet id from data source , when i am creating ec2 instance and sg in existing vpc via terraform'},
#  {'tags': ['php', 'permissions', 'ftp'],
#   'owner': {'account_id': 27828749,
#    'reputation': 1,
#    'user_id': 21247590,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/6c433581002eddb861c24e4559428683?s=256&d=identicon&r=PG',
#    'display_name': 'Glenn',
#    'link': 'https://stackoverflow.com/users/21247590/glenn'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814878,
#   'creation_date': 1677814878,
#   'question_id': 75622976,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622976/php-ftp-ftp-mkdir-fails-without-any-error-message',
#   'title': 'PHP FTP - ftp_mkdir fails without any error message'},
#  {'tags': ['java', 'database', 'hibernate', 'intellij-idea', 'dbeaver'],
#   'owner': {'account_id': 26964597,
#    'reputation': 1,
#    'user_id': 20531706,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/ALm5wu0t3hh-kKaJq6x9c-10iZY94ktc8wVxir2USuFm=k-s256',
#    'display_name': 'Nikita Parsons',
#    'link': 'https://stackoverflow.com/users/20531706/nikita-parsons'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814875,
#   'creation_date': 1677751849,
#   'last_edit_date': 1677814875,
#   'question_id': 75613980,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75613980/trying-to-connect-a-dbeaver-database-to-intellij',
#   'title': 'Trying to connect a dbeaver database to intellij'},
#  {'tags': ['php', 'mysql'],
#   'owner': {'account_id': 27923138,
#    'reputation': 1,
#    'user_id': 21322784,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYsvPvrzEDV2AJRvRoLfGoWPc6DtCo78w21BRcH=k-s256',
#    'display_name': 'Jordan Rosel',
#    'link': 'https://stackoverflow.com/users/21322784/jordan-rosel'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814875,
#   'creation_date': 1677809684,
#   'last_edit_date': 1677814875,
#   'question_id': 75622604,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622604/how-to-boost-my-mysql-datetime-query-with-thousands-of-rows',
#   'title': 'How to boost my Mysql datetime query with thousands of rows'},
#  {'tags': ['html', 'css'],
#   'owner': {'account_id': 24136874,
#    'reputation': 59,
#    'user_id': 18103650,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/4d0271c5d262ade03e371672d521ab91?s=256&d=identicon&r=PG',
#    'display_name': 'Laplas',
#    'link': 'https://stackoverflow.com/users/18103650/laplas'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677814875,
#   'creation_date': 1677774261,
#   'question_id': 75618213,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75618213/how-fix-broken-text-in-my-menu-and-broken-img',
#   'title': 'How fix broken text in my menu and broken img'},
#  {'tags': ['javascript', 'html', 'css', 'toggle', 'display'],
#   'owner': {'account_id': 27923675,
#    'reputation': 1,
#    'user_id': 21323223,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxYzzKHVlkKLmIhqKZ3ac9cuv0N2pyau0OpVJre3Zw=k-s256',
#    'display_name': 'Rathan Raju',
#    'link': 'https://stackoverflow.com/users/21323223/rathan-raju'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814867,
#   'creation_date': 1677814867,
#   'question_id': 75622974,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622974/toggle-display-with-javascript',
#   'title': 'toggle display with javascript'},
#  {'tags': ['r', 'database', 'dataframe', 'dplyr', 'grouping'],
#   'owner': {'account_id': 23991396,
#    'reputation': 69,
#    'user_id': 17977503,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gi_TgCyQRKlQ3bSU-vZB0PvHnKr8h3OOsZX80QD2Q=k-s256',
#    'display_name': 'Marnee Roundtree',
#    'link': 'https://stackoverflow.com/users/17977503/marnee-roundtree'},
#   'is_answered': True,
#   'view_count': 22,
#   'accepted_answer_id': 75622601,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1677814859,
#   'creation_date': 1677809067,
#   'last_edit_date': 1677809676,
#   'question_id': 75622561,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622561/r-grouping-character-data-into-numeric',
#   'title': 'R - Grouping character data into numeric'},
#  {'tags': ['c#',
#    'azure',
#    'asp.net-core',
#    'azure-authentication',
#    'blazor-hybrid'],
#   'owner': {'account_id': 17003522,
#    'reputation': 1471,
#    'user_id': 12300287,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/v8TOr.jpg?s=256&g=1',
#    'display_name': 'Lukas',
#    'link': 'https://stackoverflow.com/users/12300287/lukas'},
#   'is_answered': False,
#   'view_count': 17,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677814856,
#   'creation_date': 1677791126,
#   'question_id': 75620820,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75620820/how-to-implement-sign-in-with-azure-ad-in-a-blazor-hybrid-application',
#   'title': 'How to implement sign-in with Azure AD in a Blazor Hybrid application?'},
#  {'tags': ['performance',
#    'testing',
#    'automation',
#    'correlation',
#    'loadrunner'],
#   'owner': {'account_id': 24888610,
#    'reputation': 21,
#    'user_id': 18760894,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/fc5908bc93272821ecfe63ee52743214?s=256&d=identicon&r=PG',
#    'display_name': 'afirdaus04',
#    'link': 'https://stackoverflow.com/users/18760894/afirdaus04'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814855,
#   'creation_date': 1677814855,
#   'question_id': 75622971,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622971/is-it-possible-to-correlate-specific-id-using-loadrunner',
#   'title': 'Is it possible to correlate specific ID using Loadrunner?'},
#  {'tags': ['node.js', 'puppeteer'],
#   'owner': {'account_id': 15569367,
#    'reputation': 125,
#    'user_id': 11232218,
#    'user_type': 'registered',
#    'profile_image': 'https://lh5.googleusercontent.com/-D_kNYBb45lE/AAAAAAAAAAI/AAAAAAAAIB0/UWPH_ViJjJs/photo.jpg?sz=256',
#    'display_name': 'Emmanuel Oliveira',
#    'link': 'https://stackoverflow.com/users/11232218/emmanuel-oliveira'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814850,
#   'creation_date': 1677814850,
#   'question_id': 75622970,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622970/there-is-a-way-to-import-nodejs-scripts-into-mabl-with-puppeteer',
#   'title': 'There is a way to import nodejs scripts into Mabl with puppeteer?'},
#  {'tags': ['javascript', 'arrays', 'multidimensional-array'],
#   'owner': {'account_id': 21555483,
#    'reputation': 1,
#    'user_id': 15890809,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/CdYYU.jpg?s=256&g=1',
#    'display_name': 'garikarta',
#    'link': 'https://stackoverflow.com/users/15890809/garikarta'},
#   'is_answered': False,
#   'view_count': 17,
#   'closed_date': 1677814594,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814850,
#   'creation_date': 1677813990,
#   'last_edit_date': 1677814850,
#   'question_id': 75622902,
#   'link': 'https://stackoverflow.com/questions/75622902/javascript-comparation-array',
#   'closed_reason': 'Not suitable for this site',
#   'title': 'Javascript comparation array'},
#  {'tags': ['javascript', 'node.js', 'node-modules'],
#   'owner': {'account_id': 26762791,
#    'reputation': 1,
#    'user_id': 20360452,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/5a2589719b002424b25eeb320077b81a?s=256&d=identicon&r=PG',
#    'display_name': 'Gabriel Oliveira',
#    'link': 'https://stackoverflow.com/users/20360452/gabriel-oliveira'},
#   'is_answered': False,
#   'view_count': 68,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1677814807,
#   'creation_date': 1666978597,
#   'question_id': 74239007,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/74239007/start-a-puppetter-in-gitpod',
#   'title': 'Start a puppetter in gitpod'},
#  {'tags': ['javascript', 'google-apps-script', 'google-sheets'],
#   'owner': {'account_id': 16631003,
#    'reputation': 23,
#    'user_id': 12018855,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/4427dab3bf6feacd9583324513e3f382?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'NestoJosa',
#    'link': 'https://stackoverflow.com/users/12018855/nestojosa'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814799,
#   'creation_date': 1677814122,
#   'last_edit_date': 1677814799,
#   'question_id': 75622916,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622916/how-to-add-automatically-add-a-formula-to-a-cell-of-a-newly-inserted-row',
#   'title': 'How to add automatically add a formula to a cell of a newly inserted row?'},
#  {'tags': ['angular', 'typescript', 'ionic-framework'],
#   'owner': {'account_id': 21903542,
#    'reputation': 93,
#    'user_id': 16188928,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgVFNa2VUFxGacn2DwEf5xig25cZiqOSRstTXOT_Q=k-s256',
#    'display_name': 'Steven',
#    'link': 'https://stackoverflow.com/users/16188928/steven'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814796,
#   'creation_date': 1677814796,
#   'question_id': 75622968,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622968/why-does-console-show-error-when-i-declare-datetime-in-ionic',
#   'title': 'why does console show error when I declare datetime in ionic'},
#  {'tags': ['google-chrome-extension', 'knockout.js'],
#   'owner': {'account_id': 27806745,
#    'reputation': 1,
#    'user_id': 21229978,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp4L3iLO5KMuzu8smyACCRxKybWYToKc3g36sqQG=k-s256',
#    'display_name': 'Franklin Tardencilla',
#    'link': 'https://stackoverflow.com/users/21229978/franklin-tardencilla'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814793,
#   'creation_date': 1677812717,
#   'last_edit_date': 1677814793,
#   'question_id': 75622821,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622821/how-to-update-knockout-js-input-field-from-content-script-on-chrome-extension',
#   'title': 'How to update knockout js input field from content script on Chrome extension?'},
#  {'tags': ['python', 'data-analysis'],
#   'owner': {'account_id': 20543617,
#    'reputation': 60,
#    'user_id': 15078021,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/f28d235f944388b0a98633ff46880ac3?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Prima',
#    'link': 'https://stackoverflow.com/users/15078021/prima'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814774,
#   'creation_date': 1677814774,
#   'question_id': 75622967,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622967/how-to-find-peak-hours-transcation-using-group-by-in-python',
#   'title': 'how to find peak hours transcation using group by in python'},
#  {'tags': ['python', 'plotly'],
#   'owner': {'account_id': 17824149,
#    'reputation': 191,
#    'user_id': 12945785,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/10b08972868adf17bb7adfa40bcccbf9?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Jacques',
#    'link': 'https://stackoverflow.com/users/12945785/jacques'},
#   'is_answered': False,
#   'view_count': 17,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1677814772,
#   'creation_date': 1677764875,
#   'question_id': 75616311,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75616311/plotly-add-legend-in-hover-graph',
#   'title': 'Plotly add legend in hover graph'},
#  {'tags': ['sql', 'elixir', 'ecto'],
#   'owner': {'account_id': 20583504,
#    'reputation': 11,
#    'user_id': 15108984,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/bcccce4e12789305975ac7945641f0ee?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Billbryson78',
#    'link': 'https://stackoverflow.com/users/15108984/billbryson78'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814771,
#   'creation_date': 1677814771,
#   'question_id': 75622965,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622965/dynamic-elixir-ecto-query',
#   'title': 'Dynamic Elixir Ecto Query'},
#  {'tags': ['javascript', 'vue.js', 'vuejs2', 'vue-component', 'vuejs3'],
#   'owner': {'account_id': 27638742,
#    'reputation': 1,
#    'user_id': 21096140,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp5mT6rhHUe7HzxgGgOaCpah2urXBnV7LhFeAHcj=k-s256',
#    'display_name': 'nataly ren',
#    'link': 'https://stackoverflow.com/users/21096140/nataly-ren'},
#   'is_answered': False,
#   'view_count': 88,
#   'answer_count': 3,
#   'score': 0,
#   'last_activity_date': 1677814768,
#   'creation_date': 1676898438,
#   'last_edit_date': 1676904607,
#   'question_id': 75509635,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75509635/nexttick-uses-in-vuejs-and-component-update',
#   'title': 'nextTick uses in vuejs and component update'},
#  {'tags': ['visual-studio-code'],
#   'owner': {'account_id': 27919330,
#    'reputation': 1,
#    'user_id': 21319842,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1a530a6b698d6d61abb1b8efef295b0b?s=256&d=identicon&r=PG',
#    'display_name': 'lichangwei',
#    'link': 'https://stackoverflow.com/users/21319842/lichangwei'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814767,
#   'creation_date': 1677814767,
#   'question_id': 75622964,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622964/build-vscode-why-packaging-software-date-error-please-help-why-1980',
#   'title': 'build vscode. Why packaging software date error, please help. Why 1980'},
#  {'tags': ['vue.js', 'vuejs3', 'vue-router'],
#   'owner': {'account_id': 550716,
#    'reputation': 3238,
#    'user_id': 160059,
#    'user_type': 'registered',
#    'accept_rate': 62,
#    'profile_image': 'https://www.gravatar.com/avatar/f1b7d5b19fd83b3ed1f91311ddfa9022?s=256&d=identicon&r=PG',
#    'display_name': 'rendom',
#    'link': 'https://stackoverflow.com/users/160059/rendom'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814753,
#   'creation_date': 1677814424,
#   'last_edit_date': 1677814753,
#   'question_id': 75622941,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622941/vue3-router-2-routers-with-different-history',
#   'title': 'vue3 router - 2 routers with different history'},
#  {'tags': ['swift', 'swiftui', 'swiftui-navigationlink'],
#   'owner': {'account_id': 27923695,
#    'reputation': 1,
#    'user_id': 21323238,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c67eeebb014e88975f606d8507bb4030?s=256&d=identicon&r=PG',
#    'display_name': 'WPD2050',
#    'link': 'https://stackoverflow.com/users/21323238/wpd2050'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814748,
#   'creation_date': 1677814748,
#   'question_id': 75622963,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622963/double-back-buttons-in-swift-nav-view',
#   'title': 'Double Back Buttons in Swift Nav View'},
#  {'tags': ['python-3.x', 'qt', 'thread-safety', 'pyside6'],
#   'owner': {'account_id': 4534975,
#    'reputation': 353,
#    'user_id': 3684433,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/a34CF.png?s=256&g=1',
#    'display_name': 'maldata',
#    'link': 'https://stackoverflow.com/users/3684433/maldata'},
#   'is_answered': True,
#   'view_count': 16,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1677814745,
#   'creation_date': 1677799850,
#   'question_id': 75621819,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75621819/how-to-manage-python-callbacks-executed-from-a-c-library-in-a-qt-pyside6-applica',
#   'title': 'How to manage python callbacks executed from a C library in a Qt/PySide6 application?'},
#  {'tags': ['sql', 'elasticsearch', 'grafana', 'opensearch'],
#   'owner': {'account_id': 3420730,
#    'reputation': 1255,
#    'user_id': 2868465,
#    'user_type': 'registered',
#    'accept_rate': 64,
#    'profile_image': 'https://i.stack.imgur.com/VJ8Gy.jpg?s=256&g=1',
#    'display_name': 'rrlamichhane',
#    'link': 'https://stackoverflow.com/users/2868465/rrlamichhane'},
#   'is_answered': True,
#   'view_count': 15,
#   'accepted_answer_id': 75622774,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1677814738,
#   'creation_date': 1677162445,
#   'last_edit_date': 1677814738,
#   'question_id': 75546158,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75546158/how-to-configure-opensearch-elasticsearch-sql-plug-in-as-a-datasource-in-grafana',
#   'title': 'How to configure OpenSearch/ElasticSearch SQL plug-in as a datasource in Grafana?'},
#  {'tags': ['r', 'large-data', 'imbalanced-data', 'smote'],
#   'owner': {'account_id': 27923362,
#    'reputation': 1,
#    'user_id': 21322962,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c8e1d4b8a4faa93944e15bc26de3adba?s=256&d=identicon&r=PG',
#    'display_name': 'Surfer1560',
#    'link': 'https://stackoverflow.com/users/21322962/surfer1560'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814734,
#   'creation_date': 1677810980,
#   'last_edit_date': 1677814734,
#   'question_id': 75622692,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622692/themistomek-returning-0-observations',
#   'title': 'themis::tomek() returning 0 observations'},
#  {'tags': ['docker', 'kubernetes', 'containers', 'containerd', 'harbor'],
#   'owner': {'account_id': 24106733,
#    'reputation': 1,
#    'user_id': 18077825,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1787d1a6ddf124d44303dfce1c758931?s=256&d=identicon&r=PG',
#    'display_name': 'Prodigalgal',
#    'link': 'https://stackoverflow.com/users/18077825/prodigalgal'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814726,
#   'creation_date': 1677814588,
#   'last_edit_date': 1677814726,
#   'question_id': 75622952,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622952/failed-to-unpack-image-on-snapshotter-overlayfs-unexpected-media-type-text-html',
#   'title': 'failed to unpack image on snapshotter overlayfs: unexpected media type text/html'},
#  {'tags': ['admin', 'visual-studio-2022'],
#   'owner': {'account_id': 11724184,
#    'reputation': 35,
#    'user_id': 9878657,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/0ec62cdd8e13e5cf6ccabef78ba4274d?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Paulo Eduardo Pilon',
#    'link': 'https://stackoverflow.com/users/9878657/paulo-eduardo-pilon'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 0,
#   'score': -2,
#   'last_activity_date': 1677814718,
#   'creation_date': 1677807048,
#   'last_edit_date': 1677814718,
#   'question_id': 75622415,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622415/visual-studio-2022-once-run-as-admin-never-goes-back-to-normal',
#   'title': 'Visual Studio 2022 once run as ADMIN never goes back to normal'},
#  {'tags': ['php', 'xml', 'php-8'],
#   'owner': {'account_id': 27923526,
#    'reputation': 1,
#    'user_id': 21323099,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/3ebd8bf961241fd19ecad0ae9d923345?s=256&d=identicon&r=PG',
#    'display_name': 'fishman1019',
#    'link': 'https://stackoverflow.com/users/21323099/fishman1019'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1677814717,
#   'creation_date': 1677814717,
#   'question_id': 75622961,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/75622961/why-did-php-8-break-my-foreach-loop-which-works-fine-in-php-7-4-and-before',
#   'title': 'Why did php 8 break my foreach loop which works fine in php 7.4 and before?'},
#  {'tags': ['python', 'python-3.x', 'multiprocessing', 'generator'],
#   'owner': {'account_id': 2410286,
#    'reputation': 317,
#    'user_id': 2105525,
#    'user_type': 'registered',
#    'accept_rate': 50,
#    'profile_image': 'https://i.stack.imgur.com/2AGIx.png?s=256&g=1',
#    'display_name': 'Akababa',
#    'link': 'https://stackoverflow.com/users/2105525/akababa'},
#   'is_answered': True,
#   'view_count': 2135,
#   'accepted_answer_id': 48135880,
#   'answer_count': 2,
#   'score': 6,
#   'last_activity_date': 1677814716,
#   'creation_date': 1515311826,
#   'last_edit_date': 1515315836,
#   'question_id': 48135348,
#   'content_license': 'CC BY-SA 3.0',
#   'link': 'https://stackoverflow.com/questions/48135348/lazy-processpoolexecutor-in-python',
#   'title': 'lazy processpoolexecutor in Python?'}]

# %% [markdown]
# ### access each question & it's links from the stack overflow

# %%
for data in response.json()["items"]:
    print(data["title"])
    print(data["link"])
    print()
# Out:
# how to group route by name in laravel
# https://stackoverflow.com/questions/75622977/how-to-group-route-by-name-in-laravel
#
# How to call subnet id from data source , when i am creating ec2 instance and sg in existing vpc via terraform
# https://stackoverflow.com/questions/75622895/how-to-call-subnet-id-from-data-source-when-i-am-creating-ec2-instance-and-sg
#
# PHP FTP - ftp_mkdir fails without any error message
# https://stackoverflow.com/questions/75622976/php-ftp-ftp-mkdir-fails-without-any-error-message
#
# Trying to connect a dbeaver database to intellij
# https://stackoverflow.com/questions/75613980/trying-to-connect-a-dbeaver-database-to-intellij
#
# How to boost my Mysql datetime query with thousands of rows
# https://stackoverflow.com/questions/75622604/how-to-boost-my-mysql-datetime-query-with-thousands-of-rows
#
# How fix broken text in my menu and broken img
# https://stackoverflow.com/questions/75618213/how-fix-broken-text-in-my-menu-and-broken-img
#
# toggle display with javascript
# https://stackoverflow.com/questions/75622974/toggle-display-with-javascript
#
# R - Grouping character data into numeric
# https://stackoverflow.com/questions/75622561/r-grouping-character-data-into-numeric
#
# How to implement sign-in with Azure AD in a Blazor Hybrid application?
# https://stackoverflow.com/questions/75620820/how-to-implement-sign-in-with-azure-ad-in-a-blazor-hybrid-application
#
# Is it possible to correlate specific ID using Loadrunner?
# https://stackoverflow.com/questions/75622971/is-it-possible-to-correlate-specific-id-using-loadrunner
#
# There is a way to import nodejs scripts into Mabl with puppeteer?
# https://stackoverflow.com/questions/75622970/there-is-a-way-to-import-nodejs-scripts-into-mabl-with-puppeteer
#
# Javascript comparation array
# https://stackoverflow.com/questions/75622902/javascript-comparation-array
#
# Start a puppetter in gitpod
# https://stackoverflow.com/questions/74239007/start-a-puppetter-in-gitpod
#
# How to add automatically add a formula to a cell of a newly inserted row?
# https://stackoverflow.com/questions/75622916/how-to-add-automatically-add-a-formula-to-a-cell-of-a-newly-inserted-row
#
# why does console show error when I declare datetime in ionic
# https://stackoverflow.com/questions/75622968/why-does-console-show-error-when-i-declare-datetime-in-ionic
#
# How to update knockout js input field from content script on Chrome extension?
# https://stackoverflow.com/questions/75622821/how-to-update-knockout-js-input-field-from-content-script-on-chrome-extension
#
# how to find peak hours transcation using group by in python
# https://stackoverflow.com/questions/75622967/how-to-find-peak-hours-transcation-using-group-by-in-python
#
# Plotly add legend in hover graph
# https://stackoverflow.com/questions/75616311/plotly-add-legend-in-hover-graph
#
# Dynamic Elixir Ecto Query
# https://stackoverflow.com/questions/75622965/dynamic-elixir-ecto-query
#
# nextTick uses in vuejs and component update
# https://stackoverflow.com/questions/75509635/nexttick-uses-in-vuejs-and-component-update
#
# build vscode. Why packaging software date error, please help. Why 1980
# https://stackoverflow.com/questions/75622964/build-vscode-why-packaging-software-date-error-please-help-why-1980
#
# vue3 router - 2 routers with different history
# https://stackoverflow.com/questions/75622941/vue3-router-2-routers-with-different-history
#
# Double Back Buttons in Swift Nav View
# https://stackoverflow.com/questions/75622963/double-back-buttons-in-swift-nav-view
#
# How to manage python callbacks executed from a C library in a Qt/PySide6 application?
# https://stackoverflow.com/questions/75621819/how-to-manage-python-callbacks-executed-from-a-c-library-in-a-qt-pyside6-applica
#
# How to configure OpenSearch/ElasticSearch SQL plug-in as a datasource in Grafana?
# https://stackoverflow.com/questions/75546158/how-to-configure-opensearch-elasticsearch-sql-plug-in-as-a-datasource-in-grafana
#
# themis::tomek() returning 0 observations
# https://stackoverflow.com/questions/75622692/themistomek-returning-0-observations
#
# failed to unpack image on snapshotter overlayfs: unexpected media type text/html
# https://stackoverflow.com/questions/75622952/failed-to-unpack-image-on-snapshotter-overlayfs-unexpected-media-type-text-html
#
# Visual Studio 2022 once run as ADMIN never goes back to normal
# https://stackoverflow.com/questions/75622415/visual-studio-2022-once-run-as-admin-never-goes-back-to-normal
#
# Why did php 8 break my foreach loop which works fine in php 7.4 and before?
# https://stackoverflow.com/questions/75622961/why-did-php-8-break-my-foreach-loop-which-works-fine-in-php-7-4-and-before
#
# lazy processpoolexecutor in Python?
# https://stackoverflow.com/questions/48135348/lazy-processpoolexecutor-in-python

# %% [markdown]
# ### find questions and it's links that are not answered

# %%
for data in response.json()["items"]:
    if data["answer_count"] == 0:
        print(data["title"])
        print(data["link"])
    else:
        print("Skipped")
    print()
# Out:
# how to group route by name in laravel
# https://stackoverflow.com/questions/75622977/how-to-group-route-by-name-in-laravel
#
# How to call subnet id from data source , when i am creating ec2 instance and sg in existing vpc via terraform
# https://stackoverflow.com/questions/75622895/how-to-call-subnet-id-from-data-source-when-i-am-creating-ec2-instance-and-sg
#
# PHP FTP - ftp_mkdir fails without any error message
# https://stackoverflow.com/questions/75622976/php-ftp-ftp-mkdir-fails-without-any-error-message
#
# Trying to connect a dbeaver database to intellij
# https://stackoverflow.com/questions/75613980/trying-to-connect-a-dbeaver-database-to-intellij
#
# How to boost my Mysql datetime query with thousands of rows
# https://stackoverflow.com/questions/75622604/how-to-boost-my-mysql-datetime-query-with-thousands-of-rows
#
# Skipped
#
# toggle display with javascript
# https://stackoverflow.com/questions/75622974/toggle-display-with-javascript
#
# Skipped
#
# Skipped
#
# Is it possible to correlate specific ID using Loadrunner?
# https://stackoverflow.com/questions/75622971/is-it-possible-to-correlate-specific-id-using-loadrunner
#
# There is a way to import nodejs scripts into Mabl with puppeteer?
# https://stackoverflow.com/questions/75622970/there-is-a-way-to-import-nodejs-scripts-into-mabl-with-puppeteer
#
# Javascript comparation array
# https://stackoverflow.com/questions/75622902/javascript-comparation-array
#
# Skipped
#
# How to add automatically add a formula to a cell of a newly inserted row?
# https://stackoverflow.com/questions/75622916/how-to-add-automatically-add-a-formula-to-a-cell-of-a-newly-inserted-row
#
# why does console show error when I declare datetime in ionic
# https://stackoverflow.com/questions/75622968/why-does-console-show-error-when-i-declare-datetime-in-ionic
#
# How to update knockout js input field from content script on Chrome extension?
# https://stackoverflow.com/questions/75622821/how-to-update-knockout-js-input-field-from-content-script-on-chrome-extension
#
# how to find peak hours transcation using group by in python
# https://stackoverflow.com/questions/75622967/how-to-find-peak-hours-transcation-using-group-by-in-python
#
# Skipped
#
# Dynamic Elixir Ecto Query
# https://stackoverflow.com/questions/75622965/dynamic-elixir-ecto-query
#
# Skipped
#
# build vscode. Why packaging software date error, please help. Why 1980
# https://stackoverflow.com/questions/75622964/build-vscode-why-packaging-software-date-error-please-help-why-1980
#
# vue3 router - 2 routers with different history
# https://stackoverflow.com/questions/75622941/vue3-router-2-routers-with-different-history
#
# Double Back Buttons in Swift Nav View
# https://stackoverflow.com/questions/75622963/double-back-buttons-in-swift-nav-view
#
# Skipped
#
# Skipped
#
# themis::tomek() returning 0 observations
# https://stackoverflow.com/questions/75622692/themistomek-returning-0-observations
#
# failed to unpack image on snapshotter overlayfs: unexpected media type text/html
# https://stackoverflow.com/questions/75622952/failed-to-unpack-image-on-snapshotter-overlayfs-unexpected-media-type-text-html
#
# Visual Studio 2022 once run as ADMIN never goes back to normal
# https://stackoverflow.com/questions/75622415/visual-studio-2022-once-run-as-admin-never-goes-back-to-normal
#
# Why did php 8 break my foreach loop which works fine in php 7.4 and before?
# https://stackoverflow.com/questions/75622961/why-did-php-8-break-my-foreach-loop-which-works-fine-in-php-7-4-and-before
#
# Skipped

# %% [markdown]
# ## Consuming REST COUNTRIES API

# %%
url = "https://restcountries.com/v3.1/all"
json_data = json.loads(requests.get(url).text)
print(len(json_data))
json_data[0]
# Out:
# 250
# {'name': {'common': 'Gambia',
#   'official': 'Republic of the Gambia',
#   'nativeName': {'eng': {'official': 'Republic of the Gambia',
#     'common': 'Gambia'}}},
#  'tld': ['.gm'],
#  'cca2': 'GM',
#  'ccn3': '270',
#  'cca3': 'GMB',
#  'cioc': 'GAM',
#  'independent': True,
#  'status': 'officially-assigned',
#  'unMember': True,
#  'currencies': {'GMD': {'name': 'dalasi', 'symbol': 'D'}},
#  'idd': {'root': '+2', 'suffixes': ['20']},
#  'capital': ['Banjul'],
#  'altSpellings': ['GM', 'Republic of the Gambia'],
#  'region': 'Africa',
#  'subregion': 'Western Africa',
#  'languages': {'eng': 'English'},
#  'translations': {'ara': {'official': 'جمهورية غامبيا', 'common': 'غامبيا'},
#   'bre': {'official': 'Republik islamek ar Gambia', 'common': 'Gambia'},
#   'ces': {'official': 'Gambijská republika', 'common': 'Gambie'},
#   'cym': {'official': 'Republic of the Gambia', 'common': 'Gambia'},
#   'deu': {'official': 'Republik Gambia', 'common': 'Gambia'},
#   'est': {'official': 'Gambia Vabariik', 'common': 'Gambia'},
#   'fin': {'official': 'Gambian tasavalta', 'common': 'Gambia'},
#   'fra': {'official': 'République de Gambie', 'common': 'Gambie'},
#   'hrv': {'official': 'Republika Gambija', 'common': 'Gambija'},
#   'hun': {'official': 'Gambiai Köztársaság', 'common': 'Gambia'},
#   'ita': {'official': 'Repubblica del Gambia', 'common': 'Gambia'},
#   'jpn': {'official': 'ガンビア共和国', 'common': 'ガンビア'},
#   'kor': {'official': '감비아 공화국', 'common': '감비아'},
#   'nld': {'official': 'Republiek Gambia', 'common': 'Gambia'},
#   'per': {'official': 'جمهوری گامبیا', 'common': 'گامبیا'},
#   'pol': {'official': 'Republika Gambii', 'common': 'Gambia'},
#   'por': {'official': 'República da Gâmbia', 'common': 'Gâmbia'},
#   'rus': {'official': 'Республика Гамбия', 'common': 'Гамбия'},
#   'slk': {'official': 'Gambijská republika', 'common': 'Gambia'},
#   'spa': {'official': 'República de Gambia', 'common': 'Gambia'},
#   'srp': {'official': 'Република Гамбија', 'common': 'Гамбија'},
#   'swe': {'official': 'Republiken Gambia', 'common': 'Gambia'},
#   'tur': {'official': 'Gambiya Cumhuriyeti', 'common': 'Gambiya'},
#   'urd': {'official': 'جمہوریہ گیمبیا', 'common': 'گیمبیا'},
#   'zho': {'official': '冈比亚共和国', 'common': '冈比亚'}},
#  'latlng': [13.46666666, -16.56666666],
#  'landlocked': False,
#  'borders': ['SEN'],
#  'area': 10689.0,
#  'demonyms': {'eng': {'f': 'Gambian', 'm': 'Gambian'},
#   'fra': {'f': 'Gambienne', 'm': 'Gambien'}},
#  'flag': '🇬🇲',
#  'maps': {'googleMaps': 'https://goo.gl/maps/bbGBCxxtfD2A9Z4m6',
#   'openStreetMaps': 'https://www.openstreetmap.org/relation/192774'},
#  'population': 2416664,
#  'gini': {'2015': 35.9},
#  'fifa': 'GAM',
#  'car': {'signs': ['WAG'], 'side': 'right'},
#  'timezones': ['UTC+00:00'],
#  'continents': ['Africa'],
#  'flags': {'png': 'https://flagcdn.com/w320/gm.png',
#   'svg': 'https://flagcdn.com/gm.svg',
#   'alt': 'The flag of Gambia is composed of three equal horizontal bands of red, blue with white top and bottom edges, and green.'},
#  'coatOfArms': {'png': 'https://mainfacts.com/media/images/coats_of_arms/gm.png',
#   'svg': 'https://mainfacts.com/media/images/coats_of_arms/gm.svg'},
#  'startOfWeek': 'monday',
#  'capitalInfo': {'latlng': [13.45, -16.57]}}

# %%
json_data[0]["population"]
# Out:
# 2416664

# %% [markdown]
# ### Creating new dataset `countries_df`

# %%
countries_df = pd.DataFrame()
for i in range(250):
    temp_df = pd.DataFrame({
        "common_name":json_data[i]["name"]["common"],
        "official_name":json_data[i]["name"]["official"],
        "area":json_data[i]["area"],
        "population":json_data[i]["population"]        
    },index=[0])
    countries_df = countries_df.append(temp_df,ignore_index=True)

# %%
countries_df
# Out:
#                         common_name                   official_name      area  \
# 0                            Gambia          Republic of the Gambia   10689.0
# 1                     Åland Islands                   Åland Islands    1580.0
# 2                        Cape Verde          Republic of Cabo Verde    4033.0
# 3                      Turkmenistan                    Turkmenistan  488100.0
# 4                             Qatar                  State of Qatar   11586.0
# ..                              ...                             ...       ...
# 245                           Spain                Kingdom of Spain  505992.0
# 246                      Azerbaijan          Republic of Azerbaijan   86600.0
# 247                         Belgium              Kingdom of Belgium   30528.0
# 248                          Serbia              Republic of Serbia   88361.0
# 249  British Indian Ocean Territory  British Indian Ocean Territory      60.0
#
#      population
# 0       2416664
# 1         29458
# 2        555988
# 3       6031187
# 4       2881060
# ..          ...
# 245    47351567
# 246    10110116
# 247    11555997
# 248     6908224
# 249        3000
#
# [250 rows x 4 columns]

# %% [markdown]
# ### exporting the new dataset as `csv` file

# %%
countries_df.to_csv("countries.csv",index=False)

# %% [markdown]
# #### Null values check

# %%
countries_df.isna().sum()
# Out:
# common_name      0
# official_name    0
# area             0
# population       0
# dtype: int64

# %%
# !pwd /kaggle/working/countries.csv
# Out:
# /kaggle/working

# %%
temp_df = pd.DataFrame({
        "common_name":json_data[0]["name"]["common"],
        "official_name":json_data[0]["name"]["official"],
        "area":json_data[0]["area"],
        "population":json_data[0]["population"]        
    },index=[0])

temp_df.append(temp_df, ignore_index=True)
# Out:
#   common_name           official_name     area  population
# 0      Gambia  Republic of the Gambia  10689.0     2416664
# 1      Gambia  Republic of the Gambia  10689.0     2416664

# %% [markdown]
# ### dataset creation

# %%
# dataset creation
# response = requests.get("https://restcountries.com/v3.1/all").text
# data = json.loads(response)
# columns = ["commonName","officialName","unMember","capital","region","subregion","flag","timezones","area","googleMap","population"]

# df = pd.DataFrame([np.arange(0,len(columns))],columns = columns)

# for i in range(195):
#     val = [data[i]["name"]["common"],data[i]["name"]["official"],data[i]["unMember"],data[i]["capital"][0],data[i]["region"],data[i]["subregion"],data[i]["flags"]["svg"],data[i]["timezones"][0],data[i]["area"],data[i]["maps"]['googleMaps'],data[i]["population"]]
#     temp_df = pd.DataFrame([val], columns=columns)
#     df = df.append(temp_df,ignore_index=True)
#     display(df)

# %% [markdown]
# ## Consuming Polygon's api

# %%
response = requests.get("https://api.polygon.io/v3/reference/tickers?active=true&apiKey=3yOpyixTkLBex3xp0Sm6yeVtalxu4HLe")
data = json.loads(response.text)

# %%
df = pd.DataFrame()

# %%
# temp_df = pd.DataFrame(data["results"])[["ticker","name","market","type","active","currency_name"]]
# temp_df

# %%
data["next_url"]
# Out:
# 'https://api.polygon.io/v3/reference/tickers?cursor=YWN0aXZlPXRydWUmYXA9QUJDWkYlN0M1N2EzMzJmZDhjOGNjYjdiNmJmMGEyYjhlY2MxY2Q4YWE1YjMzYjE5MTQ5ZTgwMGUyODU2MTdjZTEyNzAwODNjJmFzPSZkYXRlPTIwMjMtMDMtMDMmbGltaXQ9MTAwJm9yZGVyPWFzYyZzb3J0PXRpY2tlcg'

# %%
# import time
# API_KEY = "3yOpyixTkLBex3xp0Sm6yeVtalxu4HLe"
# response = requests.get("https://api.polygon.io/v3/reference/tickers?active=true&apiKey=3yOpyixTkLBex3xp0Sm6yeVtalxu4HLe")
# data = json.loads(response.text)
# df = pd.DataFrame(data["results"])[["ticker","name","market","type","active","currency_name"]]

# for i in range(100):
#     response = requests.get(data["next_url"]+"&apiKey=3yOpyixTkLBex3xp0Sm6yeVtalxu4HLe").text
#     data = json.loads(response)
#     temp_df = pd.DataFrame(data["results"])[["ticker","name","market","type","active","currency_name"]]
#     df = df.append(temp_df,ignore_index=True)
#     display(df)
#     time.sleep(15)
#     break

# %%
import requests

url = "https://covid-193.p.rapidapi.com/countries"

headers = {
	"X-RapidAPI-Key": "6ec8b1ec34msh488cccb4e693076p196479jsn31c59bc6a759",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

response_json = json.loads(response.text)

# %%
import requests

url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"X-RapidAPI-Key": "6ec8b1ec34msh488cccb4e693076p196479jsn31c59bc6a759",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

response_json = json.loads(response.text)
response_json
# Out:
# {'get': 'statistics',
#  'parameters': [],
#  'errors': [],
#  'results': 238,
#  'response': [{'continent': 'North-America',
#    'country': 'Grenada',
#    'population': 113475,
#    'cases': {'new': None,
#     'active': 84,
#     'critical': 4,
#     'recovered': 19358,
#     '1M_pop': '173430',
#     'total': 19680},
#    'deaths': {'new': None, '1M_pop': '2097', 'total': 238},
#    'tests': {'1M_pop': '1612523', 'total': 182981},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Nicaragua',
#    'population': 6779100,
#    'cases': {'new': None,
#     'active': 14041,
#     'critical': None,
#     'recovered': 4225,
#     '1M_pop': '2728',
#     'total': 18491},
#    'deaths': {'new': None, '1M_pop': '33', 'total': 225},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'South-Sudan',
#    'population': 11618511,
#    'cases': {'new': None,
#     'active': 115,
#     'critical': 1,
#     'recovered': 18115,
#     '1M_pop': '1581',
#     'total': 18368},
#    'deaths': {'new': None, '1M_pop': '12', 'total': 138},
#    'tests': {'1M_pop': '35313', 'total': 410280},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Asia',
#    'country': 'Tajikistan',
#    'population': 9957464,
#    'cases': {'new': None,
#     'active': 397,
#     'critical': None,
#     'recovered': 17264,
#     '1M_pop': '1786',
#     'total': 17786},
#    'deaths': {'new': None, '1M_pop': '13', 'total': 125},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Dominica',
#    'population': 72344,
#    'cases': {'new': None,
#     'active': 13,
#     'critical': None,
#     'recovered': 15673,
#     '1M_pop': '217848',
#     'total': 15760},
#    'deaths': {'new': None, '1M_pop': '1023', 'total': 74},
#    'tests': {'1M_pop': '3170187', 'total': 229344},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Djibouti',
#    'population': 1016097,
#    'cases': {'new': None,
#     'active': 74,
#     'critical': None,
#     'recovered': 15427,
#     '1M_pop': '15441',
#     'total': 15690},
#    'deaths': {'new': None, '1M_pop': '186', 'total': 189},
#    'tests': {'1M_pop': '301094', 'total': 305941},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'CAR',
#    'population': 5016678,
#    'cases': {'new': None,
#     'active': 55,
#     'critical': 2,
#     'recovered': 15200,
#     '1M_pop': '3063',
#     'total': 15368},
#    'deaths': {'new': None, '1M_pop': '23', 'total': 113},
#    'tests': {'1M_pop': '16205', 'total': 81294},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Gambia',
#    'population': 2558482,
#    'cases': {'new': None,
#     'active': 25,
#     'critical': None,
#     'recovered': 12189,
#     '1M_pop': '4919',
#     'total': 12586},
#    'deaths': {'new': None, '1M_pop': '145', 'total': 372},
#    'tests': {'1M_pop': '60851', 'total': 155686},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Vanuatu',
#    'population': 321832,
#    'cases': {'new': None,
#     'active': 24,
#     'critical': None,
#     'recovered': 11976,
#     '1M_pop': '37330',
#     'total': 12014},
#    'deaths': {'new': None, '1M_pop': '44', 'total': 14},
#    'tests': {'1M_pop': '77606', 'total': 24976},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Greenland',
#    'population': 56973,
#    'cases': {'new': None,
#     'active': 9189,
#     'critical': 4,
#     'recovered': 2761,
#     '1M_pop': '210117',
#     'total': 11971},
#    'deaths': {'new': None, '1M_pop': '369', 'total': 21},
#    'tests': {'1M_pop': '2894810', 'total': 164926},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Asia',
#    'country': 'Yemen',
#    'population': 31154867,
#    'cases': {'new': None,
#     'active': 662,
#     'critical': 23,
#     'recovered': 9124,
#     '1M_pop': '383',
#     'total': 11945},
#    'deaths': {'new': None, '1M_pop': '69', 'total': 2159},
#    'tests': {'1M_pop': '10579', 'total': 329592},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Eritrea',
#    'population': 3662244,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 10086,
#     '1M_pop': '2782',
#     'total': 10189},
#    'deaths': {'new': None, '1M_pop': '28', 'total': 103},
#    'tests': {'1M_pop': '6470', 'total': 23693},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Niger',
#    'population': 26083660,
#    'cases': {'new': None,
#     'active': 729,
#     'critical': 1,
#     'recovered': 8890,
#     '1M_pop': '381',
#     'total': 9931},
#    'deaths': {'new': None, '1M_pop': '12', 'total': 312},
#    'tests': {'1M_pop': '9759', 'total': 254538},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Antigua-and-Barbuda',
#    'population': 99509,
#    'cases': {'new': None,
#     'active': 6,
#     'critical': 1,
#     'recovered': 8954,
#     '1M_pop': '91509',
#     'total': 9106},
#    'deaths': {'new': None, '1M_pop': '1467', 'total': 146},
#    'tests': {'1M_pop': '189943', 'total': 18901},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Sierra-Leone',
#    'population': 8306436,
#    'cases': {'new': None,
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '934',
#     'total': 7760},
#    'deaths': {'new': None, '1M_pop': '15', 'total': 126},
#    'tests': {'1M_pop': '31296', 'total': 259958},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'British-Virgin-Islands',
#    'population': 30596,
#    'cases': {'new': None,
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '238757',
#     'total': 7305},
#    'deaths': {'new': None, '1M_pop': '2092', 'total': 64},
#    'tests': {'1M_pop': '3508269', 'total': 107339},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Anguilla',
#    'population': 15230,
#    'cases': {'new': None,
#     'active': 13,
#     'critical': 4,
#     'recovered': 3879,
#     '1M_pop': '256336',
#     'total': 3904},
#    'deaths': {'new': None, '1M_pop': '788', 'total': 12},
#    'tests': {'1M_pop': '3373736', 'total': 51382},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Saint-Pierre-Miquelon',
#    'population': 5759,
#    'cases': {'new': None,
#     'active': 1001,
#     'critical': 1,
#     'recovered': 2449,
#     '1M_pop': '599410',
#     'total': 3452},
#    'deaths': {'new': None, '1M_pop': '347', 'total': 2},
#    'tests': {'1M_pop': '4410488', 'total': 25400},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Wallis-and-Futuna',
#    'population': 10982,
#    'cases': {'new': None,
#     'active': 2982,
#     'critical': None,
#     'recovered': 438,
#     '1M_pop': '312056',
#     'total': 3427},
#    'deaths': {'new': None, '1M_pop': '637', 'total': 7},
#    'tests': {'1M_pop': '1867419', 'total': 20508},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Tuvalu',
#    'population': 12066,
#    'cases': {'new': None,
#     'active': 2805,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '232471',
#     'total': 2805},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Saint-Helena',
#    'population': 6115,
#    'cases': {'new': None,
#     'active': 2164,
#     'critical': None,
#     'recovered': 2,
#     '1M_pop': '354211',
#     'total': 2166},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'South-America',
#    'country': 'Falkland-Islands',
#    'population': 3539,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 1930,
#     '1M_pop': '545352',
#     'total': 1930},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': '2439107', 'total': 8632},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Montserrat',
#    'population': 4965,
#    'cases': {'new': None,
#     'active': 19,
#     'critical': None,
#     'recovered': 1376,
#     '1M_pop': '282578',
#     'total': 1403},
#    'deaths': {'new': None, '1M_pop': '1611', 'total': 8},
#    'tests': {'1M_pop': '3577442', 'total': 17762},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': None,
#    'country': 'Diamond-Princess',
#    'population': None,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 699,
#     '1M_pop': None,
#     'total': 712},
#    'deaths': {'new': None, '1M_pop': None, 'total': 13},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Europe',
#    'country': 'Vatican-City',
#    'population': 799,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 29,
#     '1M_pop': '36295',
#     'total': 29},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Western-Sahara',
#    'population': 626161,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 9,
#     '1M_pop': '16',
#     'total': 10},
#    'deaths': {'new': None, '1M_pop': '2', 'total': 1},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': None,
#    'country': 'MS-Zaandam',
#    'population': None,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 7,
#     '1M_pop': None,
#     'total': 9},
#    'deaths': {'new': None, '1M_pop': None, 'total': 2},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Tokelau',
#    'population': 1378,
#    'cases': {'new': None,
#     'active': 5,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '3628',
#     'total': 5},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Asia',
#    'country': 'China',
#    'population': 1448471400,
#    'cases': {'new': None,
#     'active': 118977,
#     'critical': None,
#     'recovered': 379053,
#     '1M_pop': '347',
#     'total': 503302},
#    'deaths': {'new': None, '1M_pop': '4', 'total': 5272},
#    'tests': {'1M_pop': '110461', 'total': 160000000},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Turks-and-Caicos',
#    'population': 39741,
#    'cases': {'new': '+14',
#     'active': 22,
#     'critical': 4,
#     'recovered': 6491,
#     '1M_pop': '164842',
#     'total': 6551},
#    'deaths': {'new': None, '1M_pop': '956', 'total': 38},
#    'tests': {'1M_pop': '15387811', 'total': 611527},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Nauru',
#    'population': 10903,
#    'cases': {'new': '+126',
#     'active': 171,
#     'critical': None,
#     'recovered': 5075,
#     '1M_pop': '481244',
#     'total': 5247},
#    'deaths': {'new': None, '1M_pop': '92', 'total': 1},
#    'tests': {'1M_pop': '1881042', 'total': 20509},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Samoa',
#    'population': 202239,
#    'cases': {'new': '+13',
#     'active': 14973,
#     'critical': None,
#     'recovered': 1605,
#     '1M_pop': '82116',
#     'total': 16607},
#    'deaths': {'new': None, '1M_pop': '143', 'total': 29},
#    'tests': {'1M_pop': '926612', 'total': 187397},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Equatorial-Guinea',
#    'population': 1496662,
#    'cases': {'new': '+7',
#     'active': 139,
#     'critical': 5,
#     'recovered': 16907,
#     '1M_pop': '11512',
#     'total': 17229},
#    'deaths': {'new': None, '1M_pop': '122', 'total': 183},
#    'tests': {'1M_pop': '244342', 'total': 365697},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Saint-Martin',
#    'population': 39730,
#    'cases': {'new': '+10',
#     'active': 10795,
#     'critical': 7,
#     'recovered': 1399,
#     '1M_pop': '308507',
#     'total': 12257},
#    'deaths': {'new': None, '1M_pop': '1586', 'total': 63},
#    'tests': {'1M_pop': '2828643', 'total': 112382},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'St-Barth',
#    'population': 9945,
#    'cases': {'new': '+8',
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '546908',
#     'total': 5439},
#    'deaths': {'new': None, '1M_pop': '603', 'total': 6},
#    'tests': {'1M_pop': '7908095', 'total': 78646},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'St-Vincent-Grenadines',
#    'population': 111551,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 9466,
#     '1M_pop': '85961',
#     'total': 9589},
#    'deaths': {'new': None, '1M_pop': '1103', 'total': 123},
#    'tests': {'1M_pop': '1019292', 'total': 113703},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Kiribati',
#    'population': 123419,
#    'cases': {'new': None,
#     'active': 2292,
#     'critical': 3,
#     'recovered': 2703,
#     '1M_pop': '40618',
#     'total': 5013},
#    'deaths': {'new': None, '1M_pop': '146', 'total': 18},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Europe',
#    'country': 'Gibraltar',
#    'population': 33704,
#    'cases': {'new': '+3',
#     'active': 3733,
#     'critical': None,
#     'recovered': 16579,
#     '1M_pop': '605952',
#     'total': 20423},
#    'deaths': {'new': None, '1M_pop': '3293', 'total': 111},
#    'tests': {'1M_pop': '15852213', 'total': 534283},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Caribbean-Netherlands',
#    'population': 26647,
#    'cases': {'new': '+4',
#     'active': 1158,
#     'critical': None,
#     'recovered': 10476,
#     '1M_pop': '438023',
#     'total': 11672},
#    'deaths': {'new': None, '1M_pop': '1426', 'total': 38},
#    'tests': {'1M_pop': '1130559', 'total': 30126},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Chad',
#    'population': 17413580,
#    'cases': {'new': '+3',
#     'active': 2610,
#     'critical': None,
#     'recovered': 4874,
#     '1M_pop': '441',
#     'total': 7678},
#    'deaths': {'new': None, '1M_pop': '11', 'total': 194},
#    'tests': {'1M_pop': '10988', 'total': 191341},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Sao-Tome-and-Principe',
#    'population': 227679,
#    'cases': {'new': None,
#     'active': 0,
#     'critical': None,
#     'recovered': 6204,
#     '1M_pop': '27587',
#     'total': 6281},
#    'deaths': {'new': None, '1M_pop': '338', 'total': 77},
#    'tests': {'1M_pop': '127530', 'total': 29036},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Saint-Kitts-and-Nevis',
#    'population': 53871,
#    'cases': {'new': None,
#     'active': 2,
#     'critical': None,
#     'recovered': 6547,
#     '1M_pop': '122441',
#     'total': 6596},
#    'deaths': {'new': '+1', '1M_pop': '872', 'total': 47},
#    'tests': {'1M_pop': '2356203', 'total': 126931},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Asia',
#    'country': 'Macao',
#    'population': 667490,
#    'cases': {'new': None,
#     'active': 2,
#     'critical': None,
#     'recovered': 3391,
#     '1M_pop': '5264',
#     'total': 3514},
#    'deaths': {'new': None, '1M_pop': '181', 'total': 121},
#    'tests': {'1M_pop': '11760', 'total': 7850},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Europe',
#    'country': 'Monaco',
#    'population': 39783,
#    'cases': {'new': '+9',
#     'active': 56,
#     'critical': 4,
#     'recovered': 15992,
#     '1M_pop': '405073',
#     'total': 16115},
#    'deaths': {'new': None, '1M_pop': '1684', 'total': 67},
#    'tests': {'1M_pop': '1976875', 'total': 78646},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Bermuda',
#    'population': 61939,
#    'cases': {'new': '+15',
#     'active': 16,
#     'critical': None,
#     'recovered': 18638,
#     '1M_pop': '303750',
#     'total': 18814},
#    'deaths': {'new': None, '1M_pop': '2583', 'total': 160},
#    'tests': {'1M_pop': '16594698', 'total': 1027859},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Tonga',
#    'population': 107749,
#    'cases': {'new': '+6',
#     'active': 1156,
#     'critical': None,
#     'recovered': 15638,
#     '1M_pop': '155983',
#     'total': 16807},
#    'deaths': {'new': None, '1M_pop': '121', 'total': 13},
#    'tests': {'1M_pop': '4965327', 'total': 535009},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Marshall-Islands',
#    'population': 60057,
#    'cases': {'new': '+20',
#     'active': 73,
#     'critical': None,
#     'recovered': 15528,
#     '1M_pop': '260053',
#     'total': 15618},
#    'deaths': {'new': None, '1M_pop': '283', 'total': 17},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'North-America',
#    'country': 'Sint-Maarten',
#    'population': 43966,
#    'cases': {'new': '+4',
#     'active': 24,
#     'critical': None,
#     'recovered': 10905,
#     '1M_pop': '250648',
#     'total': 11020},
#    'deaths': {'new': None, '1M_pop': '2070', 'total': 91},
#    'tests': {'1M_pop': '1411454', 'total': 62056},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Cook-Islands',
#    'population': 17571,
#    'cases': {'new': '+3',
#     'active': 14,
#     'critical': None,
#     'recovered': 7012,
#     '1M_pop': '399977',
#     'total': 7028},
#    'deaths': {'new': None, '1M_pop': '114', 'total': 2},
#    'tests': {'1M_pop': '1120596', 'total': 19690},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Comoros',
#    'population': 907419,
#    'cases': {'new': None,
#     'active': 2,
#     'critical': None,
#     'recovered': 8838,
#     '1M_pop': '9919',
#     'total': 9001},
#    'deaths': {'new': None, '1M_pop': '177', 'total': 161},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Guinea-Bissau',
#    'population': 2063367,
#    'cases': {'new': None,
#     'active': 124,
#     'critical': 6,
#     'recovered': 8660,
#     '1M_pop': '4342',
#     'total': 8960},
#    'deaths': {'new': None, '1M_pop': '85', 'total': 176},
#    'tests': {'1M_pop': '70385', 'total': 145231},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Africa',
#    'country': 'Liberia',
#    'population': 5305117,
#    'cases': {'new': None,
#     'active': 12,
#     'critical': 2,
#     'recovered': 7783,
#     '1M_pop': '1525',
#     'total': 8090},
#    'deaths': {'new': None, '1M_pop': '56', 'total': 295},
#    'tests': {'1M_pop': '26356', 'total': 139824},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Palau',
#    'population': 18233,
#    'cases': {'new': None,
#     'active': 4,
#     'critical': None,
#     'recovered': 5976,
#     '1M_pop': '328470',
#     'total': 5989},
#    'deaths': {'new': None, '1M_pop': '494', 'total': 9},
#    'tests': {'1M_pop': '3791806', 'total': 69136},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Niue',
#    'population': 1622,
#    'cases': {'new': None,
#     'active': 6,
#     'critical': None,
#     'recovered': 784,
#     '1M_pop': '487053',
#     'total': 790},
#    'deaths': {'new': None, '1M_pop': None, 'total': None},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:08+00:00'},
#   {'continent': 'Asia',
#    'country': 'Oman',
#    'population': 5323993,
#    'cases': {'new': None,
#     'active': 10152,
#     'critical': 2,
#     'recovered': 384669,
#     '1M_pop': '75028',
#     'total': 399449},
#    'deaths': {'new': None, '1M_pop': '869', 'total': 4628},
#    'tests': {'1M_pop': '4695724', 'total': 25000000},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Luxembourg',
#    'population': 642371,
#    'cases': {'new': None,
#     'active': 7633,
#     'critical': None,
#     'recovered': 288991,
#     '1M_pop': '463528',
#     'total': 297757},
#    'deaths': {'new': None, '1M_pop': '1764', 'total': 1133},
#    'tests': {'1M_pop': '6869188', 'total': 4412567},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'El-Salvador',
#    'population': 6550389,
#    'cases': {'new': None,
#     'active': 18145,
#     'critical': 8,
#     'recovered': 179410,
#     '1M_pop': '30805',
#     'total': 201785},
#    'deaths': {'new': None, '1M_pop': '646', 'total': 4230},
#    'tests': {'1M_pop': '398467', 'total': 2610114},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Oceania',
#    'country': 'French-Polynesia',
#    'population': 284164,
#    'cases': {'new': None,
#     'active': None,
#     'critical': 7,
#     'recovered': None,
#     '1M_pop': '274338',
#     'total': 77957},
#    'deaths': {'new': None, '1M_pop': '2284', 'total': 649},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Seychelles',
#    'population': 99426,
#    'cases': {'new': None,
#     'active': 53,
#     'critical': None,
#     'recovered': 50440,
#     '1M_pop': '509575',
#     'total': 50665},
#    'deaths': {'new': None, '1M_pop': '1730', 'total': 172},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Gabon',
#    'population': 2331533,
#    'cases': {'new': None,
#     'active': 1,
#     'critical': None,
#     'recovered': 48674,
#     '1M_pop': '21008',
#     'total': 48981},
#    'deaths': {'new': None, '1M_pop': '131', 'total': 306},
#    'tests': {'1M_pop': '695641', 'total': 1621909},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Cura&ccedil;ao',
#    'population': 165529,
#    'cases': {'new': None,
#     'active': 971,
#     'critical': 3,
#     'recovered': 44720,
#     '1M_pop': '277812',
#     'total': 45986},
#    'deaths': {'new': None, '1M_pop': '1782', 'total': 295},
#    'tests': {'1M_pop': '3000640', 'total': 496693},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Isle-of-Man',
#    'population': 85732,
#    'cases': {'new': None,
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '443335',
#     'total': 38008},
#    'deaths': {'new': None, '1M_pop': '1353', 'total': 116},
#    'tests': {'1M_pop': '1758422', 'total': 150753},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Bahamas',
#    'population': 400516,
#    'cases': {'new': None,
#     'active': 292,
#     'critical': 1,
#     'recovered': 36366,
#     '1M_pop': '93607',
#     'total': 37491},
#    'deaths': {'new': None, '1M_pop': '2080', 'total': 833},
#    'tests': {'1M_pop': '643767', 'total': 257839},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Lesotho',
#    'population': 2175699,
#    'cases': {'new': None,
#     'active': 8087,
#     'critical': None,
#     'recovered': 25980,
#     '1M_pop': '15990',
#     'total': 34790},
#    'deaths': {'new': None, '1M_pop': '332', 'total': 723},
#    'tests': {'1M_pop': '198199', 'total': 431221},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Faeroe-Islands',
#    'population': 49233,
#    'cases': {'new': None,
#     'active': None,
#     'critical': 5,
#     'recovered': None,
#     '1M_pop': '703959',
#     'total': 34658},
#    'deaths': {'new': None, '1M_pop': '569', 'total': 28},
#    'tests': {'1M_pop': '15802409', 'total': 778000},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Cayman-Islands',
#    'population': 67277,
#    'cases': {'new': None,
#     'active': 22882,
#     'critical': 1,
#     'recovered': 8553,
#     '1M_pop': '467797',
#     'total': 31472},
#    'deaths': {'new': None, '1M_pop': '550', 'total': 37},
#    'tests': {'1M_pop': '3311280', 'total': 222773},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Congo',
#    'population': 5797805,
#    'cases': {'new': None,
#     'active': 983,
#     'critical': None,
#     'recovered': 24006,
#     '1M_pop': '4377',
#     'total': 25375},
#    'deaths': {'new': None, '1M_pop': '67', 'total': 386},
#    'tests': {'1M_pop': '59991', 'total': 347815},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Solomon-Islands',
#    'population': 721159,
#    'cases': {'new': None,
#     'active': None,
#     'critical': 1,
#     'recovered': None,
#     '1M_pop': '34077',
#     'total': 24575},
#    'deaths': {'new': None, '1M_pop': '212', 'total': 153},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'South-America',
#    'country': 'French-Guiana',
#    'population': 314169,
#    'cases': {'new': '+13',
#     'active': 86367,
#     'critical': 6,
#     'recovered': 11254,
#     '1M_pop': '312065',
#     'total': 98041},
#    'deaths': {'new': None, '1M_pop': '1337', 'total': 420},
#    'tests': {'1M_pop': '2072951', 'total': 651257},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Benin',
#    'population': 12784726,
#    'cases': {'new': '+1',
#     'active': 2,
#     'critical': None,
#     'recovered': 27825,
#     '1M_pop': '2189',
#     'total': 27990},
#    'deaths': {'new': None, '1M_pop': '13', 'total': 163},
#    'tests': {'1M_pop': '47268', 'total': 604310},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Mayotte',
#    'population': 286259,
#    'cases': {'new': '+2',
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '146734',
#     'total': 42004},
#    'deaths': {'new': None, '1M_pop': '657', 'total': 188},
#    'tests': {'1M_pop': '618038', 'total': 176919},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Burkina-Faso',
#    'population': 22102838,
#    'cases': {'new': None,
#     'active': 64,
#     'critical': None,
#     'recovered': 21596,
#     '1M_pop': '998',
#     'total': 22056},
#    'deaths': {'new': None, '1M_pop': '18', 'total': 396},
#    'tests': {'1M_pop': '11265', 'total': 248995},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Martinique',
#    'population': 374087,
#    'cases': {'new': '+120',
#     'active': None,
#     'critical': 12,
#     'recovered': None,
#     '1M_pop': '614314',
#     'total': 229807},
#    'deaths': {'new': '+1', '1M_pop': '2935', 'total': 1098},
#    'tests': {'1M_pop': '2215870', 'total': 828928},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Somalia',
#    'population': 16841795,
#    'cases': {'new': '+2',
#     'active': 12781,
#     'critical': None,
#     'recovered': 13182,
#     '1M_pop': '1622',
#     'total': 27324},
#    'deaths': {'new': None, '1M_pop': '81', 'total': 1361},
#    'tests': {'1M_pop': '23778', 'total': 400466},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Guinea',
#    'population': 13865691,
#    'cases': {'new': '+27',
#     'active': 43,
#     'critical': 8,
#     'recovered': 37757,
#     '1M_pop': '2760',
#     'total': 38267},
#    'deaths': {'new': None, '1M_pop': '34', 'total': 467},
#    'tests': {'1M_pop': '47607', 'total': 660107},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Timor-Leste',
#    'population': 1369429,
#    'cases': {'new': '+1',
#     'active': 178,
#     'critical': None,
#     'recovered': 23102,
#     '1M_pop': '17101',
#     'total': 23418},
#    'deaths': {'new': None, '1M_pop': '101', 'total': 138},
#    'tests': {'1M_pop': '203391', 'total': 278529},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Haiti',
#    'population': 11680283,
#    'cases': {'new': '+67',
#     'active': 239,
#     'critical': None,
#     'recovered': 33044,
#     '1M_pop': '2923',
#     'total': 34143},
#    'deaths': {'new': None, '1M_pop': '74', 'total': 860},
#    'tests': {'1M_pop': '11337', 'total': 132422},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Eswatini',
#    'population': 1184817,
#    'cases': {'new': None,
#     'active': 50,
#     'critical': None,
#     'recovered': 72726,
#     '1M_pop': '62625',
#     'total': 74199},
#    'deaths': {'new': None, '1M_pop': '1201', 'total': 1423},
#    'tests': {'1M_pop': '885119', 'total': 1048704},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Mozambique',
#    'population': 33089461,
#    'cases': {'new': '+279',
#     'active': 2051,
#     'critical': 11,
#     'recovered': 228805,
#     '1M_pop': '7044',
#     'total': 233098},
#    'deaths': {'new': '+5', '1M_pop': '68', 'total': 2242},
#    'tests': {'1M_pop': '41437', 'total': 1371127},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Barbados',
#    'population': 288023,
#    'cases': {'new': '+211',
#     'active': 13,
#     'critical': None,
#     'recovered': 106057,
#     '1M_pop': '370266',
#     'total': 106645},
#    'deaths': {'new': '+2', '1M_pop': '1996', 'total': 575},
#    'tests': {'1M_pop': '2758203', 'total': 794426},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Guadeloupe',
#    'population': 399794,
#    'cases': {'new': '+148',
#     'active': None,
#     'critical': 19,
#     'recovered': None,
#     '1M_pop': '504890',
#     'total': 201852},
#    'deaths': {'new': None, '1M_pop': '2526', 'total': 1010},
#    'tests': {'1M_pop': '2346306', 'total': 938039},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'North-Macedonia',
#    'population': 2081304,
#    'cases': {'new': '+119',
#     'active': 122,
#     'critical': None,
#     'recovered': 337068,
#     '1M_pop': '166651',
#     'total': 346852},
#    'deaths': {'new': '+9', '1M_pop': '4642', 'total': 9662},
#    'tests': {'1M_pop': '1069626', 'total': 2226216},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Ghana',
#    'population': 32395450,
#    'cases': {'new': '+5',
#     'active': 13,
#     'critical': 2,
#     'recovered': 169697,
#     '1M_pop': '5284',
#     'total': 171172},
#    'deaths': {'new': None, '1M_pop': '45', 'total': 1462},
#    'tests': {'1M_pop': '78096', 'total': 2529956},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Mauritius',
#    'population': 1274727,
#    'cases': {'new': '+19',
#     'active': 662,
#     'critical': None,
#     'recovered': 40012,
#     '1M_pop': '32726',
#     'total': 41717},
#    'deaths': {'new': None, '1M_pop': '818', 'total': 1043},
#    'tests': {'1M_pop': '281374', 'total': 358675},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Fiji',
#    'population': 909466,
#    'cases': {'new': '+13',
#     'active': 1156,
#     'critical': None,
#     'recovered': 66850,
#     '1M_pop': '75747',
#     'total': 68889},
#    'deaths': {'new': None, '1M_pop': '971', 'total': 883},
#    'tests': {'1M_pop': '734986', 'total': 668445},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Madagascar',
#    'population': 29178077,
#    'cases': {'new': '+13',
#     'active': 10,
#     'critical': None,
#     'recovered': 66433,
#     '1M_pop': '2326',
#     'total': 67865},
#    'deaths': {'new': '+1', '1M_pop': '49', 'total': 1422},
#    'tests': {'1M_pop': '18009', 'total': 525461},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Togo',
#    'population': 8680837,
#    'cases': {'new': '+3',
#     'active': 13,
#     'critical': None,
#     'recovered': 39074,
#     '1M_pop': '4536',
#     'total': 39377},
#    'deaths': {'new': None, '1M_pop': '33', 'total': 290},
#    'tests': {'1M_pop': '93113', 'total': 808297},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Belize',
#    'population': 412190,
#    'cases': {'new': '+17',
#     'active': 13,
#     'critical': 6,
#     'recovered': 70056,
#     '1M_pop': '171661',
#     'total': 70757},
#    'deaths': {'new': None, '1M_pop': '1669', 'total': 688},
#    'tests': {'1M_pop': '1397453', 'total': 576016},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Botswana',
#    'population': 2441162,
#    'cases': {'new': '+65',
#     'active': 58,
#     'critical': 1,
#     'recovered': 326868,
#     '1M_pop': '135070',
#     'total': 329727},
#    'deaths': {'new': None, '1M_pop': '1147', 'total': 2801},
#    'tests': {'1M_pop': '830300', 'total': 2026898},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Maldives',
#    'population': 540985,
#    'cases': {'new': '+3',
#     'active': 21734,
#     'critical': 25,
#     'recovered': 163687,
#     '1M_pop': '343322',
#     'total': 185732},
#    'deaths': {'new': None, '1M_pop': '575', 'total': 311},
#    'tests': {'1M_pop': '4092223', 'total': 2213831},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Uganda',
#    'population': 48432863,
#    'cases': {'new': '+26',
#     'active': 66443,
#     'critical': 3,
#     'recovered': 100431,
#     '1M_pop': '3520',
#     'total': 170504},
#    'deaths': {'new': None, '1M_pop': '75', 'total': 3630},
#    'tests': {'1M_pop': '62198', 'total': 3012408},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Rwanda',
#    'population': 13600464,
#    'cases': {'new': '+10',
#     'active': 78,
#     'critical': None,
#     'recovered': 131634,
#     '1M_pop': '9792',
#     'total': 133180},
#    'deaths': {'new': None, '1M_pop': '108', 'total': 1468},
#    'tests': {'1M_pop': '442778', 'total': 6021981},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Cameroon',
#    'population': 27911548,
#    'cases': {'new': '+64',
#     'active': 83,
#     'critical': 13,
#     'recovered': 122344,
#     '1M_pop': '4457',
#     'total': 124392},
#    'deaths': {'new': None, '1M_pop': '70', 'total': 1965},
#    'tests': {'1M_pop': '62762', 'total': 1751774},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Syria',
#    'population': 19364809,
#    'cases': {'new': '+4',
#     'active': 0,
#     'critical': None,
#     'recovered': 54303,
#     '1M_pop': '2968',
#     'total': 57467},
#    'deaths': {'new': None, '1M_pop': '163', 'total': 3164},
#    'tests': {'1M_pop': '7553', 'total': 146269},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Oceania',
#    'country': 'New-Caledonia',
#    'population': 290915,
#    'cases': {'new': '+5',
#     'active': 9,
#     'critical': 9,
#     'recovered': 79558,
#     '1M_pop': '274585',
#     'total': 79881},
#    'deaths': {'new': None, '1M_pop': '1079', 'total': 314},
#    'tests': {'1M_pop': '340182', 'total': 98964},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Liechtenstein',
#    'population': 38387,
#    'cases': {'new': '+8',
#     'active': 38,
#     'critical': 3,
#     'recovered': 21294,
#     '1M_pop': '558027',
#     'total': 21421},
#    'deaths': {'new': None, '1M_pop': '2318', 'total': 89},
#    'tests': {'1M_pop': '2929559', 'total': 112457},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Malta',
#    'population': 444033,
#    'cases': {'new': None,
#     'active': 622,
#     'critical': 4,
#     'recovered': 116028,
#     '1M_pop': '264568',
#     'total': 117477},
#    'deaths': {'new': None, '1M_pop': '1862', 'total': 827},
#    'tests': {'1M_pop': '4767893', 'total': 2117102},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Zambia',
#    'population': 19470234,
#    'cases': {'new': '+48',
#     'active': 295,
#     'critical': None,
#     'recovered': 338660,
#     '1M_pop': '17617',
#     'total': 343012},
#    'deaths': {'new': None, '1M_pop': '208', 'total': 4057},
#    'tests': {'1M_pop': '202053', 'total': 3934010},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Iceland',
#    'population': 345393,
#    'cases': {'new': '+94',
#     'active': None,
#     'critical': 2,
#     'recovered': None,
#     '1M_pop': '605377',
#     'total': 209093},
#    'deaths': {'new': None, '1M_pop': '663', 'total': 229},
#    'tests': {'1M_pop': '5780036', 'total': 1996384},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Trinidad-and-Tobago',
#    'population': 1406585,
#    'cases': {'new': '+559',
#     'active': 396,
#     'critical': 8,
#     'recovered': 184553,
#     '1M_pop': '134578',
#     'total': 189296},
#    'deaths': {'new': '+8', '1M_pop': '3090', 'total': 4347},
#    'tests': {'1M_pop': '638546', 'total': 898169},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Channel-Islands',
#    'population': 176463,
#    'cases': {'new': '+62',
#     'active': 126,
#     'critical': None,
#     'recovered': 101029,
#     '1M_pop': '574523',
#     'total': 101382},
#    'deaths': {'new': None, '1M_pop': '1286', 'total': 227},
#    'tests': {'1M_pop': '7099551', 'total': 1252808},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'South-America',
#    'country': 'Guyana',
#    'population': 794045,
#    'cases': {'new': '+3',
#     'active': 19,
#     'critical': None,
#     'recovered': 71752,
#     '1M_pop': '92021',
#     'total': 73069},
#    'deaths': {'new': None, '1M_pop': '1635', 'total': 1298},
#    'tests': {'1M_pop': '909068', 'total': 721841},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Namibia',
#    'population': 2633874,
#    'cases': {'new': '+35',
#     'active': 290,
#     'critical': None,
#     'recovered': 166776,
#     '1M_pop': '64983',
#     'total': 171156},
#    'deaths': {'new': None, '1M_pop': '1553', 'total': 4090},
#    'tests': {'1M_pop': '403460', 'total': 1062663},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Bhutan',
#    'population': 787941,
#    'cases': {'new': None,
#     'active': 1035,
#     'critical': None,
#     'recovered': 61564,
#     '1M_pop': '79473',
#     'total': 62620},
#    'deaths': {'new': None, '1M_pop': '27', 'total': 21},
#    'tests': {'1M_pop': '2923739', 'total': 2303734},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Albania',
#    'population': 2866374,
#    'cases': {'new': '+17',
#     'active': 1660,
#     'critical': None,
#     'recovered': 329152,
#     '1M_pop': '116666',
#     'total': 334408},
#    'deaths': {'new': None, '1M_pop': '1255', 'total': 3596},
#    'tests': {'1M_pop': '677173', 'total': 1941032},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Nigeria',
#    'population': 216746934,
#    'cases': {'new': '+5',
#     'active': 3526,
#     'critical': 11,
#     'recovered': 259917,
#     '1M_pop': '1230',
#     'total': 266598},
#    'deaths': {'new': None, '1M_pop': '15', 'total': 3155},
#    'tests': {'1M_pop': '26339', 'total': 5708974},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Kenya',
#    'population': 56215221,
#    'cases': {'new': '+7',
#     'active': 15,
#     'critical': 1,
#     'recovered': 337216,
#     '1M_pop': '6100',
#     'total': 342919},
#    'deaths': {'new': None, '1M_pop': '101', 'total': 5688},
#    'tests': {'1M_pop': '70569', 'total': 3967062},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Zimbabwe',
#    'population': 15331428,
#    'cases': {'new': '+206',
#     'active': 620,
#     'critical': 12,
#     'recovered': 257839,
#     '1M_pop': '17228',
#     'total': 264127},
#    'deaths': {'new': '+5', '1M_pop': '370', 'total': 5668},
#    'tests': {'1M_pop': '164744', 'total': 2525756},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Uzbekistan',
#    'population': 34382084,
#    'cases': {'new': '+139',
#     'active': 7948,
#     'critical': 23,
#     'recovered': 241486,
#     '1M_pop': '7302',
#     'total': 251071},
#    'deaths': {'new': None, '1M_pop': '48', 'total': 1637},
#    'tests': {'1M_pop': '40077', 'total': 1377915},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Asia',
#    'country': 'Kyrgyzstan',
#    'population': 6728271,
#    'cases': {'new': '+40',
#     'active': 7276,
#     'critical': 131,
#     'recovered': 196406,
#     '1M_pop': '30717',
#     'total': 206673},
#    'deaths': {'new': None, '1M_pop': '445', 'total': 2991},
#    'tests': {'1M_pop': '283460', 'total': 1907195},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Angola',
#    'population': 35027343,
#    'cases': {'new': '+22',
#     'active': 27,
#     'critical': None,
#     'recovered': 103317,
#     '1M_pop': '3006',
#     'total': 105277},
#    'deaths': {'new': None, '1M_pop': '55', 'total': 1933},
#    'tests': {'1M_pop': '42818', 'total': 1499795},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'DRC',
#    'population': 95240792,
#    'cases': {'new': '+103',
#     'active': 9964,
#     'critical': None,
#     'recovered': 84321,
#     '1M_pop': '1005',
#     'total': 95749},
#    'deaths': {'new': None, '1M_pop': '15', 'total': 1464},
#    'tests': {'1M_pop': '8890', 'total': 846704},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Senegal',
#    'population': 17653671,
#    'cases': {'new': '+4',
#     'active': 3,
#     'critical': None,
#     'recovered': 86947,
#     '1M_pop': '5037',
#     'total': 88921},
#    'deaths': {'new': None, '1M_pop': '112', 'total': 1971},
#    'tests': {'1M_pop': '64946', 'total': 1146543},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Ivory-Coast',
#    'population': 27742298,
#    'cases': {'new': '+11',
#     'active': 32,
#     'critical': None,
#     'recovered': 87342,
#     '1M_pop': '3180',
#     'total': 88208},
#    'deaths': {'new': None, '1M_pop': '30', 'total': 834},
#    'tests': {'1M_pop': '60524', 'total': 1679087},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Mauritania',
#    'population': 4901981,
#    'cases': {'new': '+1',
#     'active': 230,
#     'critical': None,
#     'recovered': 62441,
#     '1M_pop': '12988',
#     'total': 63668},
#    'deaths': {'new': None, '1M_pop': '203', 'total': 997},
#    'tests': {'1M_pop': '206030', 'total': 1009957},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Cabo-Verde',
#    'population': 567678,
#    'cases': {'new': None,
#     'active': 58,
#     'critical': 23,
#     'recovered': 62773,
#     '1M_pop': '111408',
#     'total': 63244},
#    'deaths': {'new': None, '1M_pop': '728', 'total': 413},
#    'tests': {'1M_pop': '707482', 'total': 401622},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Europe',
#    'country': 'Andorra',
#    'population': 77463,
#    'cases': {'new': '+9',
#     'active': 147,
#     'critical': 14,
#     'recovered': 47563,
#     '1M_pop': '618037',
#     'total': 47875},
#    'deaths': {'new': None, '1M_pop': '2130', 'total': 165},
#    'tests': {'1M_pop': '3225256', 'total': 249838},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Malawi',
#    'population': 20180839,
#    'cases': {'new': '+21',
#     'active': 436,
#     'critical': 67,
#     'recovered': 85580,
#     '1M_pop': '4395',
#     'total': 88702},
#    'deaths': {'new': None, '1M_pop': '133', 'total': 2686},
#    'tests': {'1M_pop': '30959', 'total': 624784},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Papua-New-Guinea',
#    'population': 9292169,
#    'cases': {'new': '+17',
#     'active': 2157,
#     'critical': 7,
#     'recovered': 43982,
#     '1M_pop': '5037',
#     'total': 46809},
#    'deaths': {'new': None, '1M_pop': '72', 'total': 670},
#    'tests': {'1M_pop': '26813', 'total': 249149},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Aruba',
#    'population': 107609,
#    'cases': {'new': '+18',
#     'active': 1370,
#     'critical': 2,
#     'recovered': 42438,
#     '1M_pop': '409297',
#     'total': 44044},
#    'deaths': {'new': None, '1M_pop': '2193', 'total': 236},
#    'tests': {'1M_pop': '1653068', 'total': 177885},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Tanzania',
#    'population': 63298550,
#    'cases': {'new': '+23',
#     'active': None,
#     'critical': 7,
#     'recovered': None,
#     '1M_pop': '677',
#     'total': 42846},
#    'deaths': {'new': None, '1M_pop': '13', 'total': 846},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'North-America',
#    'country': 'Jamaica',
#    'population': 2985094,
#    'cases': {'new': None,
#     'active': 48301,
#     'critical': None,
#     'recovered': 102393,
#     '1M_pop': '51655',
#     'total': 154196},
#    'deaths': {'new': None, '1M_pop': '1173', 'total': 3502},
#    'tests': {'1M_pop': '396633', 'total': 1183986},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'South-America',
#    'country': 'Suriname',
#    'population': 596831,
#    'cases': {'new': '+240',
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '138175',
#     'total': 82467},
#    'deaths': {'new': '+4', '1M_pop': '2352', 'total': 1404},
#    'tests': {'1M_pop': '404398', 'total': 241357},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:07+00:00'},
#   {'continent': 'Africa',
#    'country': 'Sudan',
#    'population': 45992020,
#    'cases': {'new': None,
# ...
#   {'continent': 'Europe',
#    'country': 'Ireland',
#    'population': 5020199,
#    'cases': {'new': None,
#     'active': 3033,
#     'critical': 13,
#     'recovered': 1692126,
#     '1M_pop': '339399',
#     'total': 1703850},
#    'deaths': {'new': None, '1M_pop': '1731', 'total': 8691},
#    'tests': {'1M_pop': '2595829', 'total': 13031576},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Slovenia',
#    'population': 2078034,
#    'cases': {'new': '+398',
#     'active': 4445,
#     'critical': 6,
#     'recovered': 1317563,
#     '1M_pop': '639585',
#     'total': 1329079},
#    'deaths': {'new': None, '1M_pop': '3403', 'total': 7071},
#    'tests': {'1M_pop': '1365840', 'total': 2838261},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Vietnam',
#    'population': 98953541,
#    'cases': {'new': '+11',
#     'active': 868968,
#     'critical': 4,
#     'recovered': 10614783,
#     '1M_pop': '116488',
#     'total': 11526937},
#    'deaths': {'new': None, '1M_pop': '436', 'total': 43186},
#    'tests': {'1M_pop': '867342', 'total': 85826548},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Iran',
#    'population': 86022837,
#    'cases': {'new': '+358',
#     'active': 84879,
#     'critical': 312,
#     'recovered': 7339518,
#     '1M_pop': '87991',
#     'total': 7569261},
#    'deaths': {'new': '+6', '1M_pop': '1684', 'total': 144864},
#    'tests': {'1M_pop': '639771', 'total': 55034937},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Finland',
#    'population': 5554960,
#    'cases': {'new': '+2',
#     'active': 2084,
#     'critical': 21,
#     'recovered': 1451956,
#     '1M_pop': '263364',
#     'total': 1462976},
#    'deaths': {'new': None, '1M_pop': '1609', 'total': 8936},
#    'tests': {'1M_pop': '2168835', 'total': 12047792},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Switzerland',
#    'population': 8773637,
#    'cases': {'new': None,
#     'active': 3529,
#     'critical': 39,
#     'recovered': 4373026,
#     '1M_pop': '500477',
#     'total': 4391007},
#    'deaths': {'new': None, '1M_pop': '1647', 'total': 14452},
#    'tests': {'1M_pop': '2716487', 'total': 23833472},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Denmark',
#    'population': 5834950,
#    'cases': {'new': '+68',
#     'active': 904,
#     'critical': 19,
#     'recovered': 3166156,
#     '1M_pop': '544192',
#     'total': 3175332},
#    'deaths': {'new': '+3', '1M_pop': '1418', 'total': 8272},
#    'tests': {'1M_pop': '22142239', 'total': 129198860},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Sweden',
#    'population': 10218971,
#    'cases': {'new': None,
#     'active': 3761,
#     'critical': 8,
#     'recovered': 2671071,
#     '1M_pop': '264071',
#     'total': 2698535},
#    'deaths': {'new': None, '1M_pop': '2320', 'total': 23703},
#    'tests': {'1M_pop': '1906026', 'total': 19477620},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Austria',
#    'population': 9066710,
#    'cases': {'new': '+6217',
#     'active': 59219,
#     'critical': 81,
#     'recovered': 5845030,
#     '1M_pop': '653616',
#     'total': 5926148},
#    'deaths': {'new': '+2', '1M_pop': '2415', 'total': 21899},
#    'tests': {'1M_pop': '23302116', 'total': 211273524},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Saudi-Arabia',
#    'population': 35844909,
#    'cases': {'new': '+70',
#     'active': 3192,
#     'critical': 31,
#     'recovered': 816815,
#     '1M_pop': '23145',
#     'total': 829624},
#    'deaths': {'new': '+2', '1M_pop': '268', 'total': 9617},
#    'tests': {'1M_pop': '1259635', 'total': 45151519},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'North-America',
#    'country': 'Cuba',
#    'population': 11305652,
#    'cases': {'new': '+6',
#     'active': 91,
#     'critical': 2,
#     'recovered': 1103988,
#     '1M_pop': '98412',
#     'total': 1112609},
#    'deaths': {'new': None, '1M_pop': '754', 'total': 8530},
#    'tests': {'1M_pop': '1266528', 'total': 14318929},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Bahrain',
#    'population': 1783983,
#    'cases': {'new': '+233',
#     'active': 498,
#     'critical': 5,
#     'recovered': 706013,
#     '1M_pop': '396899',
#     'total': 708061},
#    'deaths': {'new': '+1', '1M_pop': '869', 'total': 1550},
#    'tests': {'1M_pop': '6020868', 'total': 10741126},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'South-America',
#    'country': 'Chile',
#    'population': 19250195,
#    'cases': {'new': '+2951',
#     'active': 6392,
#     'critical': 82,
#     'recovered': 5101501,
#     '1M_pop': '268677',
#     'total': 5172090},
#    'deaths': {'new': '+20', '1M_pop': '3335', 'total': 64197},
#    'tests': {'1M_pop': '2517943', 'total': 48470891},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Malaysia',
#    'population': 33181072,
#    'cases': {'new': '+244',
#     'active': 9469,
#     'critical': 7,
#     'recovered': 4996818,
#     '1M_pop': '151992',
#     'total': 5043252},
#    'deaths': {'new': '+5', '1M_pop': '1114', 'total': 36965},
#    'tests': {'1M_pop': '2055914', 'total': 68217426},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Israel',
#    'population': 9326000,
#    'cases': {'new': '+757',
#     'active': 6842,
#     'critical': 57,
#     'recovered': 4781252,
#     '1M_pop': '514733',
#     'total': 4800397},
#    'deaths': {'new': '+11', '1M_pop': '1319', 'total': 12303},
#    'tests': {'1M_pop': '4436346', 'total': 41373364},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Africa',
#    'country': 'South-Africa',
#    'population': 60756135,
#    'cases': {'new': '+594',
#     'active': 49356,
#     'critical': 192,
#     'recovered': 3912506,
#     '1M_pop': '66898',
#     'total': 4064457},
#    'deaths': {'new': None, '1M_pop': '1689', 'total': 102595},
#    'tests': {'1M_pop': '441027', 'total': 26795090},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Europe',
#    'country': 'Serbia',
#    'population': 8653016,
#    'cases': {'new': '+1818',
#     'active': 14705,
#     'critical': 10,
#     'recovered': 2461837,
#     '1M_pop': '288267',
#     'total': 2494381},
#    'deaths': {'new': '+13', '1M_pop': '2062', 'total': 17839},
#    'tests': {'1M_pop': '1434764', 'total': 12415033},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Africa',
#    'country': 'Morocco',
#    'population': 37772756,
#    'cases': {'new': '+12',
#     'active': 71,
#     'critical': 3,
#     'recovered': 1256104,
#     '1M_pop': '33688',
#     'total': 1272471},
#    'deaths': {'new': None, '1M_pop': '431', 'total': 16296},
#    'tests': {'1M_pop': '343827', 'total': 12987287},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Sri-Lanka',
#    'population': 21575842,
#    'cases': {'new': None,
#     'active': 1,
#     'critical': None,
#     'recovered': 655200,
#     '1M_pop': '31147',
#     'total': 672031},
#    'deaths': {'new': None, '1M_pop': '780', 'total': 16830},
#    'tests': {'1M_pop': '300619', 'total': 6486117},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Myanmar',
#    'population': 55227143,
#    'cases': {'new': '+10',
#     'active': 44,
#     'critical': None,
#     'recovered': 614401,
#     '1M_pop': '11479',
#     'total': 633935},
#    'deaths': {'new': None, '1M_pop': '353', 'total': 19490},
#    'tests': {'1M_pop': '182179', 'total': 10061205},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Africa',
#    'country': 'Ethiopia',
#    'population': 120812698,
#    'cases': {'new': '+28',
#     'active': 5169,
#     'critical': 1,
#     'recovered': 487273,
#     '1M_pop': '4139',
#     'total': 500014},
#    'deaths': {'new': None, '1M_pop': '63', 'total': 7572},
#    'tests': {'1M_pop': '45452', 'total': 5491134},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:06+00:00'},
#   {'continent': 'Asia',
#    'country': 'Turkey',
#    'population': 85561976,
#    'cases': {'new': None,
#     'active': None,
#     'critical': None,
#     'recovered': None,
#     '1M_pop': '199186',
#     'total': 17042722},
#    'deaths': {'new': None, '1M_pop': '1186', 'total': 101492},
#    'tests': {'1M_pop': '1902052', 'total': 162743369},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'Italy',
#    'population': 60262770,
#    'cases': {'new': None,
#     'active': 169105,
#     'critical': 133,
#     'recovered': 25219653,
#     '1M_pop': '424422',
#     'total': 25576852},
#    'deaths': {'new': None, '1M_pop': '3121', 'total': 188094},
#    'tests': {'1M_pop': '4441601', 'total': 267663187},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'Spain',
#    'population': 46719142,
#    'cases': {'new': '+1056',
#     'active': 36888,
#     'critical': 231,
#     'recovered': 13607068,
#     '1M_pop': '294597',
#     'total': 13763336},
#    'deaths': {'new': '+26', '1M_pop': '2555', 'total': 119380},
#    'tests': {'1M_pop': '10082298', 'total': 471036328},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'South-America',
#    'country': 'Brazil',
#    'population': 215353593,
#    'cases': {'new': '+10528',
#     'active': 123266,
#     'critical': None,
#     'recovered': 36241001,
#     '1M_pop': '172105',
#     'total': 37063464},
#    'deaths': {'new': '+110', '1M_pop': '3247', 'total': 699197},
#    'tests': {'1M_pop': '296146', 'total': 63776166},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'UK',
#    'population': 68497907,
#    'cases': {'new': None,
#     'active': 40834,
#     'critical': None,
#     'recovered': 24094535,
#     '1M_pop': '355363',
#     'total': 24341615},
#    'deaths': {'new': None, '1M_pop': '3011', 'total': 206246},
#    'tests': {'1M_pop': '7628357', 'total': 522526476},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Asia',
#    'country': 'S-Korea',
#    'population': 51329899,
#    'cases': {'new': '+7561',
#     'active': 183359,
#     'critical': 129,
#     'recovered': 30316211,
#     '1M_pop': '594850',
#     'total': 30533573},
#    'deaths': {'new': '+15', '1M_pop': '662', 'total': 34003},
#    'tests': {'1M_pop': '307892', 'total': 15804065},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'Germany',
#    'population': 83883596,
#    'cases': {'new': None,
#     'active': 292179,
#     'critical': None,
#     'recovered': 37729600,
#     '1M_pop': '455273',
#     'total': 38189954},
#    'deaths': {'new': None, '1M_pop': '2005', 'total': 168175},
#    'tests': {'1M_pop': '1458359', 'total': 122332384},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Asia',
#    'country': 'India',
#    'population': 1406631776,
#    'cases': {'new': None,
#     'active': 2439,
#     'critical': None,
#     'recovered': 44153668,
#     '1M_pop': '31769',
#     'total': 44686879},
#    'deaths': {'new': None, '1M_pop': '377', 'total': 530772},
#    'tests': {'1M_pop': '653188', 'total': 918794368},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'Russia',
#    'population': 145805947,
#    'cases': {'new': '+14096',
#     'active': 258482,
#     'critical': None,
#     'recovered': 21645346,
#     '1M_pop': '152943',
#     'total': 22300004},
#    'deaths': {'new': '+39', '1M_pop': '2717', 'total': 396176},
#    'tests': {'1M_pop': '1875095', 'total': 273400000},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Asia',
#    'country': 'Japan',
#    'population': 125584838,
#    'cases': {'new': '+11506',
#     'active': 11470201,
#     'critical': 141,
#     'recovered': 21687770,
#     '1M_pop': '264606',
#     'total': 33230544},
#    'deaths': {'new': '+87', '1M_pop': '578', 'total': 72573},
#    'tests': {'1M_pop': '759535', 'total': 95386077},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Oceania',
#    'country': 'Oceania',
#    'population': None,
#    'cases': {'new': None,
#     'active': 135938,
#     'critical': 64,
#     'recovered': 13834567,
#     '1M_pop': None,
#     'total': 13996622},
#    'deaths': {'new': None, '1M_pop': None, 'total': 26117},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Asia',
#    'country': 'Asia',
#    'population': None,
#    'cases': {'new': '+35754',
#     'active': 13829459,
#     'critical': 15473,
#     'recovered': 199025377,
#     '1M_pop': None,
#     'total': 214391787},
#    'deaths': {'new': '+174', '1M_pop': None, 'total': 1536951},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'South-America',
#    'country': 'South-America',
#    'population': None,
#    'cases': {'new': '+3199',
#     'active': 391121,
#     'critical': 10187,
#     'recovered': 66284653,
#     '1M_pop': None,
#     'total': 68026550},
#    'deaths': {'new': '+29', '1M_pop': None, 'total': 1350776},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'Europe',
#    'population': None,
#    'cases': {'new': '+31350',
#     'active': 2423514,
#     'critical': 6479,
#     'recovered': 241964781,
#     '1M_pop': None,
#     'total': 246406093},
#    'deaths': {'new': '+107', '1M_pop': None, 'total': 2017798},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Africa',
#    'country': 'Africa',
#    'population': None,
#    'cases': {'new': '+660',
#     'active': 460970,
#     'critical': 548,
#     'recovered': 12076169,
#     '1M_pop': None,
#     'total': 12795729},
#    'deaths': {'new': None, '1M_pop': None, 'total': 258590},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'Europe',
#    'country': 'France',
#    'population': 65584518,
#    'cases': {'new': '+4196',
#     'active': 71804,
#     'critical': 869,
#     'recovered': 39394139,
#     '1M_pop': '604273',
#     'total': 39630952},
#    'deaths': {'new': '+21', '1M_pop': '2516', 'total': 165009},
#    'tests': {'1M_pop': '4139547', 'total': 271490188},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'North-America',
#    'country': 'North-America',
#    'population': None,
#    'cases': {'new': '+2781',
#     'active': 3152059,
#     'critical': 7737,
#     'recovered': 119895508,
#     '1M_pop': None,
#     'total': 124659478},
#    'deaths': {'new': '+21', '1M_pop': None, 'total': 1611911},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'All',
#    'country': 'All',
#    'population': None,
#    'cases': {'new': '+73744',
#     'active': 20393061,
#     'critical': 40488,
#     'recovered': 653081761,
#     '1M_pop': '87273',
#     'total': 680276980},
#    'deaths': {'new': '+331', '1M_pop': '872.7', 'total': 6802158},
#    'tests': {'1M_pop': None, 'total': None},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'},
#   {'continent': 'North-America',
#    'country': 'USA',
#    'population': 334805269,
#    'cases': {'new': '+2775',
#     'active': 1449183,
#     'critical': 2571,
#     'recovered': 102753421,
#     '1M_pop': '314657',
#     'total': 105348767},
#    'deaths': {'new': '+21', '1M_pop': '3423', 'total': 1146163},
#    'tests': {'1M_pop': '3486392', 'total': 1167262304},
#    'day': '2023-03-02',
#    'time': '2023-03-02T23:15:05+00:00'}]}
